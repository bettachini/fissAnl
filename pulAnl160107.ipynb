# %%
#import matplotlib
#import numpy as np
#import matplotlib.pyplot as plt

from pulAnl160106 import * # En pulAnl160106.py residen todas las funciones desarroladas en pulAnl160106.ipynb

# %matplotlib inline
# coding=utf-8

# %% [markdown]
# # Procesamiento

# %% [markdown]
# Los mas recientes son `pul151009`+ `zxx.npy.npz`, se extiende `z01-z10`.
#
# En fecha `151008` `z01-z13`,
#
# `151007`,
#
# `151006`,
#
# `151005`
#
# y un experimental `01`.
#
# Las adquisicones fueron registradas con `pul151005` donde se detalla bajo el título **Journal** que se midió.
#
# Como criterio procesaré de más reciente a mas antigüo hasta reproducir el procedimiento sobre las mediciones que se anlizan en `anl150807`. Los analizados en tal caso fueron anchos temporales de los pulsos de:
#
# pulser= np.array([50e-9, 75e-9, 100E-9, 125E-9, 150E-9, 175E-9, 200E-9, 225E-9, 250e-9, 275e-9,
#                   3.0567943706e-07, 3.25173964034e-07, 3.47919077404e-07, 3.73028928851e-07, 3.98022673964e-07, 4.23560985145e-07 ])

# %% [markdown]
# # Actual

# %% [markdown]
# # 151008 - Rechazo alto

# %%
# 164 ns

# Selección de adqusición
mes= 10
dia= 8
rango= np.arange(13,14)
prop= 0.25
rechazo= 0.15

# Proceso de adquisición
anchosPulser, areasPulser, maxsPulser, tausAMC, areasTotalAMC, areasSubidaAMC, maximosAMC= agregadorPulser(mes, dia, rango, prop, rechazo)

# %%
# enmascarado para quedarse con Gaussiana
enmascaradaPorSobre= 0.3
mascara, tausAMCComprimidos = binner(tausAMC, enmascaradaPorSobre)
res164= todoEnmascarado2(mascara, anchosPulser, areasPulser, maxsPulser, tausAMCComprimidos, areasTotalAMC, areasSubidaAMC, maximosAMC)
# Out:
# puntos campana 1049
# anchoPulser= 	1.636e-07 	+/- 1.868e-11 	 s
# areaPulser= 	5.792e-09 	+/- 7.007e-13 	 Vs
# maxPulser= 	-2.023e-02 	+/- 3.404e-05 	 V
# tauAMC= 	1.311e-07 	+/- 5.806e-10 	 s
# areaSubidaAMC= 	8.199e-08 	+/- 4.428e-10 	 Vs
# areaTotalAMC= 	1.942e-07 	+/- 9.460e-10 	 Vs
# maximoAMC=  	9.217e-01 	+/- 2.222e-03 	 V

# %%
# 150 ns

# Selección de adqusición
mes= 10
dia= 8
rango= np.arange(12,13)
prop= 0.25
rechazo= 0.15

# Proceso de adquisición
anchosPulser, areasPulser, maxsPulser, tausAMC, areasTotalAMC, areasSubidaAMC, maximosAMC= agregadorPulser(mes, dia, rango, prop, rechazo)

# %%
# enmascarado para quedarse con Gaussiana
enmascaradaPorSobre= 0.3
mascara, tausAMCComprimidos = binner(tausAMC, enmascaradaPorSobre)
res150= todoEnmascarado2(mascara, anchosPulser, areasPulser, maxsPulser, tausAMCComprimidos, areasTotalAMC, areasSubidaAMC, maximosAMC)
# Out:
# puntos campana 1016
# anchoPulser= 	1.502e-07 	+/- 1.999e-11 	 s
# areaPulser= 	5.275e-09 	+/- 6.529e-13 	 Vs
# maxPulser= 	-2.020e-02 	+/- 3.573e-05 	 V
# tauAMC= 	1.245e-07 	+/- 6.088e-10 	 s
# areaSubidaAMC= 	7.256e-08 	+/- 4.478e-10 	 Vs
# areaTotalAMC= 	1.763e-07 	+/- 9.936e-10 	 Vs
# maximoAMC=  	8.474e-01 	+/- 2.287e-03 	 V

# %%
# 139 ns

# Selección de adqusición
mes= 10
dia= 8
rango= np.arange(11,12)
prop= 0.25
rechazo= 0.15

# Proceso de adquisición
anchosPulser, areasPulser, maxsPulser, tausAMC, areasTotalAMC, areasSubidaAMC, maximosAMC= agregadorPulser(mes, dia, rango, prop, rechazo)

# %%
# enmascarado para quedarse con Gaussiana
enmascaradaPorSobre= 0.3
mascara, tausAMCComprimidos = binner(tausAMC, enmascaradaPorSobre)
res139= todoEnmascarado2(mascara, anchosPulser, areasPulser, maxsPulser, tausAMCComprimidos, areasTotalAMC, areasSubidaAMC, maximosAMC)
# Out:
# puntos campana 948
# anchoPulser= 	1.391e-07 	+/- 2.047e-11 	 s
# areaPulser= 	4.850e-09 	+/- 6.133e-13 	 Vs
# maxPulser= 	-2.078e-02 	+/- 3.548e-05 	 V
# tauAMC= 	1.228e-07 	+/- 7.017e-10 	 s
# areaSubidaAMC= 	6.673e-08 	+/- 4.416e-10 	 Vs
# areaTotalAMC= 	1.633e-07 	+/- 1.007e-09 	 Vs
# maximoAMC=  	7.858e-01 	+/- 2.344e-03 	 V

# %%
# 126 ns

# Selección de adqusición
mes= 10
dia= 8
rango= np.arange(10,11)
prop= 0.25
rechazo= 0.15

# Proceso de adquisición
anchosPulser, areasPulser, maxsPulser, tausAMC, areasTotalAMC, areasSubidaAMC, maximosAMC= agregadorPulser(mes, dia, rango, prop, rechazo)

# %%
# enmascarado para quedarse con Gaussiana
enmascaradaPorSobre= 0.3
mascara, tausAMCComprimidos = binner(tausAMC, enmascaradaPorSobre)
res126= todoEnmascarado2(mascara, anchosPulser, areasPulser, maxsPulser, tausAMCComprimidos, areasTotalAMC, areasSubidaAMC, maximosAMC)
# Out:
# puntos campana 872
# anchoPulser= 	1.257e-07 	+/- 2.228e-11 	 s
# areaPulser= 	4.330e-09 	+/- 6.178e-13 	 Vs
# maxPulser= 	-2.147e-02 	+/- 3.907e-05 	 V
# tauAMC= 	1.156e-07 	+/- 6.975e-10 	 s
# areaSubidaAMC= 	5.863e-08 	+/- 4.475e-10 	 Vs
# areaTotalAMC= 	1.458e-07 	+/- 1.047e-09 	 Vs
# maximoAMC=  	7.203e-01 	+/- 2.539e-03 	 V

# %%
# 113 ns

# Selección de adqusición
mes= 10
dia= 8
rango= np.arange(9,10)
prop= 0.25
rechazo= 0.15

# Proceso de adquisición
anchosPulser, areasPulser, maxsPulser, tausAMC, areasTotalAMC, areasSubidaAMC, maximosAMC= agregadorPulser(mes, dia, rango, prop, rechazo)

# %%
# enmascarado para quedarse con Gaussiana
enmascaradaPorSobre= 0.3
mascara, tausAMCComprimidos = binner(tausAMC, enmascaradaPorSobre)
res113= todoEnmascarado2(mascara, anchosPulser, areasPulser, maxsPulser, tausAMCComprimidos, areasTotalAMC, areasSubidaAMC, maximosAMC)
# Out:
# puntos campana 900
# anchoPulser= 	1.134e-07 	+/- 2.177e-11 	 s
# areaPulser= 	3.860e-09 	+/- 5.806e-13 	 Vs
# maxPulser= 	-2.143e-02 	+/- 4.194e-05 	 V
# tauAMC= 	1.111e-07 	+/- 7.021e-10 	 s
# areaSubidaAMC= 	5.127e-08 	+/- 4.063e-10 	 Vs
# areaTotalAMC= 	1.294e-07 	+/- 9.981e-10 	 Vs
# maximoAMC=  	6.573e-01 	+/- 2.481e-03 	 V

# %%
# 101 ns

# Selección de adqusición
mes= 10
dia= 8
rango= np.arange(8,9) # Conjunto 1-2
prop= 0.25
rechazo= 0.15

# Proceso de adquisición
anchosPulser, areasPulser, maxsPulser, tausAMC, areasTotalAMC, areasSubidaAMC, maximosAMC= agregadorPulser(mes, dia, rango, prop, rechazo)

# %%
# enmascarado para quedarse con Gaussiana
enmascaradaPorSobre= 0.3
mascara, tausAMCComprimidos = binner(tausAMC, enmascaradaPorSobre)
res101= todoEnmascarado2(mascara, anchosPulser, areasPulser, maxsPulser, tausAMCComprimidos, areasTotalAMC, areasSubidaAMC, maximosAMC)
# Out:
# puntos campana 889
# anchoPulser= 	1.012e-07 	+/- 2.271e-11 	 s
# areaPulser= 	3.385e-09 	+/- 5.084e-13 	 Vs
# maxPulser= 	-1.957e-02 	+/- 3.903e-05 	 V
# tauAMC= 	1.061e-07 	+/- 7.637e-10 	 s
# areaSubidaAMC= 	4.372e-08 	+/- 4.138e-10 	 Vs
# areaTotalAMC= 	1.113e-07 	+/- 9.927e-10 	 Vs
# maximoAMC=  	5.888e-01 	+/- 2.509e-03 	 V

# %%
# 88 ns

# Selección de adqusición
mes= 10
dia= 8
rango= np.arange(7,8) # Conjunto 1-2
prop= 0.25
rechazo= 0.15

# Proceso de adquisición
anchosPulser, areasPulser, maxsPulser, tausAMC, areasTotalAMC, areasSubidaAMC, maximosAMC= agregadorPulser(mes, dia, rango, prop, rechazo)

# %%
# enmascarado para quedarse con Gaussiana
enmascaradaPorSobre= 0.3
mascara, tausAMCComprimidos = binner(tausAMC, enmascaradaPorSobre)
res88= todoEnmascarado2(mascara, anchosPulser, areasPulser, maxsPulser, tausAMCComprimidos, areasTotalAMC, areasSubidaAMC, maximosAMC)
# Out:
# puntos campana 838
# anchoPulser= 	8.831e-08 	+/- 1.942e-11 	 s
# areaPulser= 	2.905e-09 	+/- 4.641e-13 	 Vs
# maxPulser= 	-2.002e-02 	+/- 3.931e-05 	 V
# tauAMC= 	1.021e-07 	+/- 7.739e-10 	 s
# areaSubidaAMC= 	3.693e-08 	+/- 3.953e-10 	 Vs
# areaTotalAMC= 	9.542e-08 	+/- 9.516e-10 	 Vs
# maximoAMC=  	5.211e-01 	+/- 2.646e-03 	 V

# %%
# 62 ns

# Selección de adqusición
mes= 10
dia= 8
rango= np.arange(5,6) # Conjunto 1-2
prop= 0.25
rechazo= 0.12

# Proceso de adquisición
anchosPulser, areasPulser, maxsPulser, tausAMC, areasTotalAMC, areasSubidaAMC, maximosAMC= agregadorPulser(mes, dia, rango, prop, rechazo)

# %%
# enmascarado para quedarse con Gaussiana
enmascaradaPorSobre= 0.4
mascara, tausAMCComprimidos = binner(tausAMC, enmascaradaPorSobre)
res62= todoEnmascarado2(mascara, anchosPulser, areasPulser, maxsPulser, tausAMCComprimidos, areasTotalAMC, areasSubidaAMC, maximosAMC)
# Out:
# puntos campana 747
# anchoPulser= 	6.208e-08 	+/- 2.218e-11 	 s
# areaPulser= 	1.922e-09 	+/- 3.737e-13 	 Vs
# maxPulser= 	-1.634e-02 	+/- 3.929e-05 	 V
# tauAMC= 	1.018e-07 	+/- 1.192e-09 	 s
# areaSubidaAMC= 	2.495e-08 	+/- 3.915e-10 	 Vs
# areaTotalAMC= 	6.572e-08 	+/- 9.874e-10 	 Vs
# maximoAMC=  	3.741e-01 	+/- 2.647e-03 	 V

# %%
# 50 ns

# Selección de adqusición
mes= 10
dia= 8
rango= np.arange(4,5) # Conjunto 1-2
prop= 0.25
rechazo= 0.15

# Proceso de adquisición
anchosPulser, areasPulser, maxsPulser, tausAMC, areasTotalAMC, areasSubidaAMC, maximosAMC= agregadorPulser(mes, dia, rango, prop, rechazo)

# %%
# enmascarado para quedarse con Gaussiana
enmascaradaPorSobre= 0.25
mascara, tausAMCComprimidos = binner(tausAMC, enmascaradaPorSobre)
res50= todoEnmascarado2(mascara, anchosPulser, areasPulser, maxsPulser, tausAMCComprimidos, areasTotalAMC, areasSubidaAMC, maximosAMC)
# Out:
# puntos campana 768
# anchoPulser= 	5.071e-08 	+/- 2.188e-11 	 s
# areaPulser= 	1.484e-09 	+/- 3.198e-13 	 Vs
# maxPulser= 	-1.803e-02 	+/- 4.642e-05 	 V
# tauAMC= 	9.871e-08 	+/- 1.160e-09 	 s
# areaSubidaAMC= 	1.882e-08 	+/- 3.511e-10 	 Vs
# areaTotalAMC= 	4.937e-08 	+/- 9.129e-10 	 Vs
# maximoAMC=  	3.132e-01 	+/- 2.665e-03 	 V

# %%
# 174 ns

# Selección de adqusición
mes= 10
dia= 8
rango= np.arange(3,4) # Conjunto 1-2
prop= 0.25
rechazo= 0.09

# Proceso de adquisición
anchosPulser, areasPulser, maxsPulser, tausAMC, areasTotalAMC, areasSubidaAMC, maximosAMC= agregadorPulser(mes, dia, rango, prop, rechazo)

# %%
# enmascarado para quedarse con Gaussiana
enmascaradaPorSobre= 0.4
mascara, tausAMCComprimidos = binner(tausAMC, enmascaradaPorSobre)
res174= todoEnmascarado2(mascara, anchosPulser, areasPulser, maxsPulser, tausAMCComprimidos, areasTotalAMC, areasSubidaAMC, maximosAMC)
# Out:
# puntos campana 1179
# anchoPulser= 	1.740e-07 	+/- 1.675e-11 	 s
# areaPulser= 	6.194e-09 	+/- 6.626e-13 	 Vs
# maxPulser= 	-2.097e-02 	+/- 3.111e-05 	 V
# tauAMC= 	1.377e-07 	+/- 6.503e-10 	 s
# areaSubidaAMC= 	8.737e-08 	+/- 4.877e-10 	 Vs
# areaTotalAMC= 	2.093e-07 	+/- 1.003e-09 	 Vs
# maximoAMC=  	1.039e+00 	+/- 2.275e-03 	 V

# %%
# 152 ns

# Selección de adqusición
mes= 10
dia= 8
rango= np.arange(1,3) # Conjunto 1-2
prop= 0.25
rechazo= 0.09

# Proceso de adquisición
anchosPulser, areasPulser, maxsPulser, tausAMC, areasTotalAMC, areasSubidaAMC, maximosAMC= agregadorPulser(mes, dia, rango, prop, rechazo)

# %%
# enmascarado para quedarse con Gaussiana
enmascaradaPorSobre= 0.4
mascara, tausAMCComprimidos = binner(tausAMC, enmascaradaPorSobre)
res152= todoEnmascarado2(mascara, anchosPulser, areasPulser, maxsPulser, tausAMCComprimidos, areasTotalAMC, areasSubidaAMC, maximosAMC)
# Out:
# puntos campana 1756
# anchoPulser= 	1.518e-07 	+/- 2.683e-11 	 s
# areaPulser= 	5.378e-09 	+/- 1.141e-12 	 Vs
# maxPulser= 	-1.682e-02 	+/- 1.053e-04 	 V
# tauAMC= 	1.282e-07 	+/- 5.147e-10 	 s
# areaSubidaAMC= 	7.453e-08 	+/- 3.681e-10 	 Vs
# areaTotalAMC= 	1.819e-07 	+/- 7.671e-10 	 Vs
# maximoAMC=  	9.125e-01 	+/- 2.139e-03 	 V

# %% [markdown]
# # 151009 - rechazo igual (original 0.03)

# %%
# 179 ns

# Selección de adqusición
mes= 10
dia= 9
rango= np.arange(1,2)
prop= 0.25
rechazo= 0.09

# Proceso de adquisición
anchosPulser, areasPulser, maxsPulser, tausAMC, areasTotalAMC, areasSubidaAMC, maximosAMC= agregadorPulser(mes, dia, rango, prop, rechazo)

# %%
# enmascarado para quedarse con Gaussiana
enmascaradaPorSobre= 0.35
mascara, tausAMCComprimidos = binner(tausAMC, enmascaradaPorSobre)
res179= todoEnmascarado2(mascara, anchosPulser, areasPulser, maxsPulser, tausAMCComprimidos, areasTotalAMC, areasSubidaAMC, maximosAMC)
# Out:
# puntos campana 1197
# anchoPulser= 	1.786e-07 	+/- 4.401e-11 	 s
# areaPulser= 	6.453e-09 	+/- 1.111e-12 	 Vs
# maxPulser= 	-1.505e-02 	+/- 1.716e-04 	 V
# tauAMC= 	1.390e-07 	+/- 5.987e-10 	 s
# areaSubidaAMC= 	9.123e-08 	+/- 4.672e-10 	 Vs
# areaTotalAMC= 	2.155e-07 	+/- 9.425e-10 	 Vs
# maximoAMC=  	1.116e+00 	+/- 2.190e-03 	 V

# %%
# 176 ns

# Selección de adqusición
mes= 10
dia= 9
rango= np.arange(2,3)
prop= 0.25
rechazo= 0.09

# Proceso de adquisición
anchosPulser, areasPulser, maxsPulser, tausAMC, areasTotalAMC, areasSubidaAMC, maximosAMC= agregadorPulser(mes, dia, rango, prop, rechazo)

# %%
# enmascarado para quedarse con Gaussiana
enmascaradaPorSobre= 0.4
mascara, tausAMCComprimidos = binner(tausAMC, enmascaradaPorSobre)
res176= todoEnmascarado2(mascara, anchosPulser, areasPulser, maxsPulser, tausAMCComprimidos, areasTotalAMC, areasSubidaAMC, maximosAMC)
# Out:
# puntos campana 1209
# anchoPulser= 	1.760e-07 	+/- 1.730e-11 	 s
# areaPulser= 	6.296e-09 	+/- 6.776e-13 	 Vs
# maxPulser= 	-2.073e-02 	+/- 4.481e-05 	 V
# tauAMC= 	1.380e-07 	+/- 6.259e-10 	 s
# areaSubidaAMC= 	8.880e-08 	+/- 4.741e-10 	 Vs
# areaTotalAMC= 	2.115e-07 	+/- 9.578e-10 	 Vs
# maximoAMC=  	1.098e+00 	+/- 2.124e-03 	 V

# %%
# 188 ns

# Selección de adqusición
mes= 10
dia= 9
rango= np.arange(3,4)
prop= 0.25
rechazo= 0.09

# Proceso de adquisición
anchosPulser, areasPulser, maxsPulser, tausAMC, areasTotalAMC, areasSubidaAMC, maximosAMC= agregadorPulser(mes, dia, rango, prop, rechazo)

# %%
# enmascarado para quedarse con Gaussiana
enmascaradaPorSobre= 0.4
mascara, tausAMCComprimidos = binner(tausAMC, enmascaradaPorSobre)
res188= todoEnmascarado2(mascara, anchosPulser, areasPulser, maxsPulser, tausAMCComprimidos, areasTotalAMC, areasSubidaAMC, maximosAMC)
# Out:
# puntos campana 1209
# anchoPulser= 	1.884e-07 	+/- 1.523e-11 	 s
# areaPulser= 	6.756e-09 	+/- 7.005e-13 	 Vs
# maxPulser= 	-2.179e-02 	+/- 3.247e-05 	 V
# tauAMC= 	1.438e-07 	+/- 6.239e-10 	 s
# areaSubidaAMC= 	9.735e-08 	+/- 4.873e-10 	 Vs
# areaTotalAMC= 	2.266e-07 	+/- 9.567e-10 	 Vs
# maximoAMC=  	1.149e+00 	+/- 2.107e-03 	 V

# %%
# 200 ns

# Selección de adqusición
mes= 10
dia= 9
rango= np.arange(4,5)
prop= 0.25
rechazo= 0.09

# Proceso de adquisición
anchosPulser, areasPulser, maxsPulser, tausAMC, areasTotalAMC, areasSubidaAMC, maximosAMC= agregadorPulser(mes, dia, rango, prop, rechazo)

# %%
# enmascarado para quedarse con Gaussiana
enmascaradaPorSobre= 0.35
mascara, tausAMCComprimidos = binner(tausAMC, enmascaradaPorSobre)
res200= todoEnmascarado2(mascara, anchosPulser, areasPulser, maxsPulser, tausAMCComprimidos, areasTotalAMC, areasSubidaAMC, maximosAMC)
# Out:
# puntos campana 1226
# anchoPulser= 	1.999e-07 	+/- 1.574e-11 	 s
# areaPulser= 	7.187e-09 	+/- 7.343e-13 	 Vs
# maxPulser= 	-2.155e-02 	+/- 3.284e-05 	 V
# tauAMC= 	1.483e-07 	+/- 5.902e-10 	 s
# areaSubidaAMC= 	1.039e-07 	+/- 4.927e-10 	 Vs
# areaTotalAMC= 	2.382e-07 	+/- 9.562e-10 	 Vs
# maximoAMC=  	1.188e+00 	+/- 2.092e-03 	 V

# %%
# 213 ns

# Selección de adqusición
mes= 10
dia= 9
rango= np.arange(5,6)
prop= 0.25
rechazo= 0.09

# Proceso de adquisición
anchosPulser, areasPulser, maxsPulser, tausAMC, areasTotalAMC, areasSubidaAMC, maximosAMC= agregadorPulser(mes, dia, rango, prop, rechazo)

# %%
# enmascarado para quedarse con Gaussiana
enmascaradaPorSobre= 0.35
mascara, tausAMCComprimidos = binner(tausAMC, enmascaradaPorSobre)
res213= todoEnmascarado2(mascara, anchosPulser, areasPulser, maxsPulser, tausAMCComprimidos, areasTotalAMC, areasSubidaAMC, maximosAMC)
# Out:
# puntos campana 1219
# anchoPulser= 	2.134e-07 	+/- 1.548e-11 	 s
# areaPulser= 	7.701e-09 	+/- 7.995e-13 	 Vs
# maxPulser= 	-1.996e-02 	+/- 3.367e-05 	 V
# tauAMC= 	1.532e-07 	+/- 5.629e-10 	 s
# areaSubidaAMC= 	1.143e-07 	+/- 5.297e-10 	 Vs
# areaTotalAMC= 	2.563e-07 	+/- 9.712e-10 	 Vs
# maximoAMC=  	1.237e+00 	+/- 2.150e-03 	 V

# %%
# 225 ns

# Selección de adqusición
mes= 10
dia= 9
rango= np.arange(6,7)
prop= 0.25
rechazo= 0.09

# Proceso de adquisición
anchosPulser, areasPulser, maxsPulser, tausAMC, areasTotalAMC, areasSubidaAMC, maximosAMC= agregadorPulser(mes, dia, rango, prop, rechazo)

# %%
# enmascarado para quedarse con Gaussiana
enmascaradaPorSobre= 0.4
mascara, tausAMCComprimidos = binner(tausAMC, enmascaradaPorSobre)
res225= todoEnmascarado2(mascara, anchosPulser, areasPulser, maxsPulser, tausAMCComprimidos, areasTotalAMC, areasSubidaAMC, maximosAMC)
# Out:
# puntos campana 1234
# anchoPulser= 	2.253e-07 	+/- 1.506e-11 	 s
# areaPulser= 	8.153e-09 	+/- 7.817e-13 	 Vs
# maxPulser= 	-2.054e-02 	+/- 3.174e-05 	 V
# tauAMC= 	1.607e-07 	+/- 5.708e-10 	 s
# areaSubidaAMC= 	1.241e-07 	+/- 5.262e-10 	 Vs
# areaTotalAMC= 	2.721e-07 	+/- 9.388e-10 	 Vs
# maximoAMC=  	1.273e+00 	+/- 2.105e-03 	 V

# %%
# 238 ns

# Selección de adqusición
mes= 10
dia= 9
rango= np.arange(7,8)
prop= 0.25
rechazo= 0.09

# Proceso de adquisición
anchosPulser, areasPulser, maxsPulser, tausAMC, areasTotalAMC, areasSubidaAMC, maximosAMC= agregadorPulser(mes, dia, rango, prop, rechazo)

# %%
# enmascarado para quedarse con Gaussiana
enmascaradaPorSobre= 0.35
mascara, tausAMCComprimidos = binner(tausAMC, enmascaradaPorSobre)
res238= todoEnmascarado2(mascara, anchosPulser, areasPulser, maxsPulser, tausAMCComprimidos, areasTotalAMC, areasSubidaAMC, maximosAMC)
# Out:
# puntos campana 1210
# anchoPulser= 	2.380e-07 	+/- 1.496e-11 	 s
# areaPulser= 	8.620e-09 	+/- 8.311e-13 	 Vs
# maxPulser= 	-2.259e-02 	+/- 3.368e-05 	 V
# tauAMC= 	1.654e-07 	+/- 5.643e-10 	 s
# areaSubidaAMC= 	1.332e-07 	+/- 5.763e-10 	 Vs
# areaTotalAMC= 	2.870e-07 	+/- 1.014e-09 	 Vs
# maximoAMC=  	1.312e+00 	+/- 2.194e-03 	 V

# %% [markdown]
# # Das analise

# %%
anchoPulserS= np.array([res50.anchoPulser, res62.anchoPulser, res88.anchoPulser, res101.anchoPulser, res113.anchoPulser, 
               res126.anchoPulser, res139.anchoPulser, res150.anchoPulser, res152.anchoPulser, res164.anchoPulser,
               res174.anchoPulser, res176.anchoPulser, res179.anchoPulser, res188.anchoPulser,
               res200.anchoPulser, res213.anchoPulser, res225.anchoPulser, res238.anchoPulser
               ])
anchoPulserS
# Out:
# array([  5.07109375e-08,   6.20765730e-08,   8.83097852e-08,
#          1.01161755e-07,   1.13408444e-07,   1.25651376e-07,
#          1.39084810e-07,   1.50228740e-07,   1.51785194e-07,
#          1.63565682e-07,   1.73981340e-07,   1.75993714e-07,
#          1.78589474e-07,   1.88368569e-07,   1.99861011e-07,
#          2.13423134e-07,   2.25282982e-07,   2.37981157e-07])

# %%
anchoPulserS.size
# Out:
# 18

# %%
anchoPulserErrorS= np.array([res50.anchoPulserError, res62.anchoPulserError, res88.anchoPulserError, res101.anchoPulserError,
                    res113.anchoPulserError, res126.anchoPulserError, res139.anchoPulserError, res150.anchoPulserError,
                    res152.anchoPulserError, res164.anchoPulserError, res174.anchoPulserError, res176.anchoPulserError,
                    res179.anchoPulserError, res188.anchoPulserError, res200.anchoPulserError, res213.anchoPulserError,
                    res225.anchoPulserError, res238.anchoPulserError
               ])
anchoPulserErrorS
# Out:
# array([  2.18773053e-11,   2.21758461e-11,   1.94204425e-11,
#          2.27084377e-11,   2.17668750e-11,   2.22827859e-11,
#          2.04722145e-11,   1.99919455e-11,   2.68333334e-11,
#          1.86794405e-11,   1.67502640e-11,   1.72997719e-11,
#          4.40141742e-11,   1.52269666e-11,   1.57380634e-11,
#          1.54796597e-11,   1.50564173e-11,   1.49560832e-11])

# %%
areaPulserS= np.array([res50.areaPulser, res62.areaPulser, res88.areaPulser, res101.areaPulser,
                    res113.areaPulser, res126.areaPulser, res139.areaPulser, res150.areaPulser,
                    res152.areaPulser, res164.areaPulser, res174.areaPulser, res176.areaPulser,
                    res179.areaPulser, res188.areaPulser, res200.areaPulser, res213.areaPulser,
                    res225.areaPulser, res238.areaPulser
               ])
areaPulserS
# Out:
# array([  1.48379519e-09,   1.92159010e-09,   2.90467407e-09,
#          3.38488782e-09,   3.86028504e-09,   4.32978992e-09,
#          4.85023813e-09,   5.27481962e-09,   5.37789976e-09,
#          5.79183062e-09,   6.19431746e-09,   6.29626239e-09,
#          6.45301366e-09,   6.75634243e-09,   7.18722096e-09,
#          7.70115714e-09,   8.15288289e-09,   8.62007620e-09])

# %%
areaPulserErrorS= np.array([res50.areaPulserError, res62.areaPulserError, res88.areaPulserError, res101.areaPulserError,
                    res113.areaPulserError, res126.areaPulserError, res139.areaPulserError, res150.areaPulserError,
                    res152.areaPulserError, res164.areaPulserError, res174.areaPulserError, res176.areaPulserError,
                    res179.areaPulserError, res188.areaPulserError, res200.areaPulserError, res213.areaPulserError,
                    res225.areaPulserError, res238.areaPulserError
               ])
areaPulserErrorS
# Out:
# array([  3.19799589e-13,   3.73682730e-13,   4.64068765e-13,
#          5.08374684e-13,   5.80582662e-13,   6.17847936e-13,
#          6.13308701e-13,   6.52888096e-13,   1.14067267e-12,
#          7.00705506e-13,   6.62605837e-13,   6.77582810e-13,
#          1.11132608e-12,   7.00477431e-13,   7.34304276e-13,
#          7.99522156e-13,   7.81672162e-13,   8.31077843e-13])

# %%
areaSubidaAMCS= np.array([res50.areaSubidaAMC, res62.areaSubidaAMC, res88.areaSubidaAMC, res101.areaSubidaAMC,
                    res113.areaSubidaAMC, res126.areaSubidaAMC, res139.areaSubidaAMC, res150.areaSubidaAMC,
                    res152.areaSubidaAMC, res164.areaSubidaAMC, res174.areaSubidaAMC, res176.areaSubidaAMC,
                    res179.areaSubidaAMC, res188.areaSubidaAMC, res200.areaSubidaAMC, res213.areaSubidaAMC,
                    res225.areaSubidaAMC, res238.areaSubidaAMC
               ])
areaSubidaAMCS
# Out:
# array([  1.88237845e-08,   2.49508573e-08,   3.69326876e-08,
#          4.37178206e-08,   5.12744459e-08,   5.86301989e-08,
#          6.67288933e-08,   7.25564521e-08,   7.45302618e-08,
#          8.19850351e-08,   8.73737420e-08,   8.88042989e-08,
#          9.12287404e-08,   9.73466781e-08,   1.03891998e-07,
#          1.14340512e-07,   1.24089025e-07,   1.33153535e-07])

# %%
areaSubidaAMCErrorS= np.array([res50.areaSubidaAMCError, res62.areaSubidaAMCError, res88.areaSubidaAMCError, res101.areaSubidaAMCError,
                    res113.areaSubidaAMCError, res126.areaSubidaAMCError, res139.areaSubidaAMCError, res150.areaSubidaAMCError,
                    res152.areaSubidaAMCError, res164.areaSubidaAMCError, res174.areaSubidaAMCError, res176.areaSubidaAMCError,
                    res179.areaSubidaAMCError, res188.areaSubidaAMCError, res200.areaSubidaAMCError, res213.areaSubidaAMCError,
                    res225.areaSubidaAMCError, res238.areaSubidaAMCError
                    ])
areaSubidaAMCErrorS
# Out:
# array([  3.51092907e-10,   3.91542071e-10,   3.95291954e-10,
#          4.13839774e-10,   4.06253579e-10,   4.47547247e-10,
#          4.41579083e-10,   4.47791986e-10,   3.68069454e-10,
#          4.42824224e-10,   4.87745726e-10,   4.74138681e-10,
#          4.67164652e-10,   4.87311123e-10,   4.92688044e-10,
#          5.29653144e-10,   5.26152443e-10,   5.76323951e-10])

# %%
areaTotalAMCS= np.array([res50.areaTotalAMC, res62.areaTotalAMC, res88.areaTotalAMC, res101.areaTotalAMC,
                    res113.areaTotalAMC, res126.areaTotalAMC, res139.areaTotalAMC, res150.areaTotalAMC,
                    res152.areaTotalAMC, res164.areaTotalAMC, res174.areaTotalAMC, res176.areaTotalAMC,
                    res179.areaTotalAMC, res188.areaTotalAMC, res200.areaTotalAMC, res213.areaTotalAMC,
                    res225.areaTotalAMC, res238.areaTotalAMC
               ])
areaTotalAMCS
# Out:
# array([  4.93677731e-08,   6.57197742e-08,   9.54176656e-08,
#          1.11275849e-07,   1.29364133e-07,   1.45824048e-07,
#          1.63314997e-07,   1.76250774e-07,   1.81872259e-07,
#          1.94173770e-07,   2.09252441e-07,   2.11471574e-07,
#          2.15511340e-07,   2.26554690e-07,   2.38230517e-07,
#          2.56304733e-07,   2.72097217e-07,   2.87017507e-07])

# %%
areaTotalAMCErrorS= np.array([res50.areaTotalAMCError, res62.areaTotalAMCError, res88.areaTotalAMCError, res101.areaTotalAMCError,
                    res113.areaTotalAMCError, res126.areaTotalAMCError, res139.areaTotalAMCError, res150.areaTotalAMCError,
                    res152.areaTotalAMCError, res164.areaTotalAMCError, res174.areaTotalAMCError, res176.areaTotalAMCError,
                    res179.areaTotalAMCError, res188.areaTotalAMCError, res200.areaTotalAMCError, res213.areaTotalAMCError,
                    res225.areaTotalAMCError, res238.areaTotalAMCError
               ])
areaTotalAMCErrorS
# Out:
# array([  9.12904511e-10,   9.87430883e-10,   9.51556772e-10,
#          9.92728487e-10,   9.98101746e-10,   1.04747526e-09,
#          1.00667805e-09,   9.93628825e-10,   7.67127330e-10,
#          9.45961285e-10,   1.00331959e-09,   9.57790703e-10,
#          9.42460304e-10,   9.56695354e-10,   9.56197187e-10,
#          9.71154690e-10,   9.38785650e-10,   1.01446507e-09])

# %%
maxPulserS= np.array([res50.maxPulser, res62.maxPulser, res88.maxPulser, res101.maxPulser,
                    res113.maxPulser, res126.maxPulser, res139.maxPulser, res150.maxPulser,
                    res152.maxPulser, res164.maxPulser, res174.maxPulser, res176.maxPulser,
                    res179.maxPulser, res188.maxPulser, res200.maxPulser, res213.maxPulser,
                    res225.maxPulser, res238.maxPulser
               ])
maxPulserS
# Out:
# array([-0.01803212, -0.01634035, -0.02001948, -0.01956671, -0.02142911,
#        -0.02146926, -0.02077684, -0.02020043, -0.01682204, -0.02023018,
#        -0.02097041, -0.02072674, -0.01505016, -0.0217856 , -0.02155411,
#        -0.01995616, -0.02054064, -0.02259272])

# %%
maxPulserErrorS= np.array([res50.maxPulserError, res62.maxPulserError, res88.maxPulserError, res101.maxPulserError,
                    res113.maxPulserError, res126.maxPulserError, res139.maxPulserError, res150.maxPulserError,
                    res152.maxPulserError, res164.maxPulserError, res174.maxPulserError, res176.maxPulserError,
                    res179.maxPulserError, res188.maxPulserError, res200.maxPulserError, res213.maxPulserError,
                    res225.maxPulserError, res238.maxPulserError
                   ])
maxPulserErrorS
# Out:
# array([  4.64234623e-05,   3.92924077e-05,   3.93111176e-05,
#          3.90277755e-05,   4.19372321e-05,   3.90693390e-05,
#          3.54768465e-05,   3.57252520e-05,   1.05257140e-04,
#          3.40370186e-05,   3.11122589e-05,   4.48115029e-05,
#          1.71594544e-04,   3.24742286e-05,   3.28418592e-05,
#          3.36685048e-05,   3.17395024e-05,   3.36769476e-05])

# %%
maximoAMCS= np.array([res50.maximoAMC, res62.maximoAMC, res88.maximoAMC, res101.maximoAMC,
                    res113.maximoAMC, res126.maximoAMC, res139.maximoAMC, res150.maximoAMC,
                    res152.maximoAMC, res164.maximoAMC, res174.maximoAMC, res176.maximoAMC,
                    res179.maximoAMC, res188.maximoAMC, res200.maximoAMC, res213.maximoAMC,
                    res225.maximoAMC, res238.maximoAMC
                   ])
maximoAMCS
# Out:
# array([ 0.31320841,  0.37414893,  0.52107175,  0.58881064,  0.65729896,
#         0.72030229,  0.78584569,  0.84741086,  0.91249497,  0.92165253,
#         1.03867718,  1.09801049,  1.11644809,  1.14873585,  1.18816451,
#         1.23669484,  1.27295868,  1.3116148 ])

# %%
maximoAMCErrorS= np.array([res50.maximoAMCError, res62.maximoAMCError, res88.maximoAMCError, res101.maximoAMCError,
                    res113.maximoAMCError, res126.maximoAMCError, res139.maximoAMCError, res150.maximoAMCError,
                    res152.maximoAMCError, res164.maximoAMCError, res174.maximoAMCError, res176.maximoAMCError,
                    res179.maximoAMCError, res188.maximoAMCError, res200.maximoAMCError, res213.maximoAMCError,
                    res225.maximoAMCError, res238.maximoAMCError
                   ])
maximoAMCErrorS
# Out:
# array([ 0.00266528,  0.00264687,  0.00264594,  0.00250903,  0.00248121,
#         0.0025392 ,  0.00234409,  0.00228744,  0.00213942,  0.00222226,
#         0.00227454,  0.00212384,  0.0021897 ,  0.00210666,  0.00209236,
#         0.0021503 ,  0.00210509,  0.00219414])

# %%
tauAMCS= np.array([res50.tauAMC, res62.tauAMC, res88.tauAMC, res101.tauAMC,
                    res113.tauAMC, res126.tauAMC, res139.tauAMC, res150.tauAMC, 
                    res152.tauAMC, res164.tauAMC, res174.tauAMC, res176.tauAMC, 
                    res179.tauAMC, res188.tauAMC, res200.tauAMC, res213.tauAMC, 
                    res225.tauAMC, res238.tauAMC
                   ])
tauAMCS
# Out:
# array([  9.87062500e-08,   1.01773494e-07,   1.02137947e-07,
#          1.06127784e-07,   1.11120889e-07,   1.15586697e-07,
#          1.22791139e-07,   1.24487402e-07,   1.28167198e-07,
#          1.31137846e-07,   1.37651908e-07,   1.38043672e-07,
#          1.38965079e-07,   1.43751530e-07,   1.48282545e-07,
#          1.53220673e-07,   1.60695948e-07,   1.65371570e-07])

# %%
tauAMCErrorS= np.array([res50.tauAMCError, res62.tauAMCError, res88.tauAMCError, res101.tauAMCError,
                    res113.tauAMCError, res126.tauAMCError, res139.tauAMCError, res150.tauAMCError,
                    res152.tauAMCError, res164.tauAMCError, res174.tauAMCError, res176.tauAMCError,
                    res179.tauAMCError, res188.tauAMCError, res200.tauAMCError, res213.tauAMCError,
                    res225.tauAMCError, res238.tauAMCError
                   ])
tauAMCErrorS
# Out:
# array([  1.16020597e-09,   1.19201191e-09,   7.73896526e-10,
#          7.63745934e-10,   7.02117041e-10,   6.97483518e-10,
#          7.01740548e-10,   6.08800421e-10,   5.14699949e-10,
#          5.80630155e-10,   6.50288957e-10,   6.25857611e-10,
#          5.98675630e-10,   6.23878529e-10,   5.90246483e-10,
#          5.62894460e-10,   5.70774062e-10,   5.64326954e-10])

# %%
np.savez_compressed('./data/calib_DB2_pulAnl160107.npz', anchoPulserS= anchoPulserS, anchoPulserErrorS= anchoPulserErrorS,
                    areaPulserS= areaPulserS, areaPulserErrorS= areaPulserErrorS,
                    areaSubidaAMCS= areaSubidaAMCS, areaSubidaAMCErrorS= areaSubidaAMCErrorS,
                    areaTotalAMCS= areaTotalAMCS, areaTotalAMCErrorS= areaTotalAMCErrorS,
                    maxPulserS= maxPulserS, maxPulserErrorS= maxPulserErrorS,
                    maximoAMCS= maximoAMCS, maximoAMCErrorS= maximoAMCErrorS,
                    tauAMCS= tauAMCS, tauAMCErrorS= tauAMCErrorS,
                    )

# %% [markdown]
# # Gráfica de comparación con anl150807

# %%
# ajuste anl150807
# resumen mediciones
pulser= np.array([50e-9, 75e-9, 100E-9, 125E-9, 150E-9, 175E-9, 200E-9, 225E-9, 250e-9, 275e-9,
                  3.0567943706e-07, 3.25173964034e-07, 3.47919077404e-07, 3.73028928851e-07, 3.98022673964e-07, 4.23560985145e-07 ])
ePulser= np. array([  5.00000000e-11,   7.50000000e-11,   1.00000000e-10, 1.25000000e-10, 1.50000000e-10, 1.75000000e-10, 2.00000000e-10,   2.25000000e-10,   2.50000000e-10, 2.75000000e-10,
         1.12326542847e-10, 3.61149009936e-11, 1.60046767424e-12, 1.9205612089e-11, 1.93293197358e-11, 8.68273042511e-12]) #  ePulser= 1E-3* pulser
tau= np.array([1.12228713858e-07, 1.17722206506e-07,  1.248E-7, 1.336E-7, 1.431E-7, 1.524E-7, 1.61053299057E-07, 1.72612455375E-07, 1.85921193093e-07, 1.95733750979e-07,
               2.0548956282e-07, 2.10277511962e-07, 2.15979591837e-07, 2.20895316804e-07, 2.22922222222e-07, 2.24811208267e-07 ])
eTau= np.array([4.78622460848e-10, 2.75376555221e-10, 1E-10, 3E-10, 5E-10, 1E-10, 6.92956670683e-11, 4.10154397471e-10, 2.78121784156e-10, 5.01511682411e-11,
                8.95396954757e-11, 1.45361392096e-10, 9.96416700311e-11, 4.54331186214e-10, 4.7668396466e-10, 9.59463232928e-11 ])

np.savez_compressed('./data/calib_DB2_anl150807.npz', pulser= pulser, ePulser= ePulser,
                    tau= tau, eTau= eTau
                    )

z4, mCov4 = np.polyfit(tau, pulser, 4, cov=True)
p4 = np.poly1d(z4)
errZ4=np.sqrt(np.diag(mCov4))

z3, mCov3 = np.polyfit(tau, pulser, 3, cov=True)
p3 = np.poly1d(z3)
errZ3=np.sqrt(np.diag(mCov3))

# %%
# ajuste actual (a)
z4a, mCov4a = np.polyfit(tauAMCS, anchoPulserS, 4, cov=True)
p4a = np.poly1d(z4a)
errZ4a=np.sqrt(np.diag(mCov4a))

z3a, mCov3a = np.polyfit(tauAMCS, anchoPulserS, 3, cov=True)
p3a = np.poly1d(z3a)
errZ3a=np.sqrt(np.diag(mCov3a))

# %%
# Ajuste orden 3
# actual vs. anl150807 
# Figura con taus pulser
fig = plt.figure(1, figsize=(9.5,6.5))
ax = plt.axes()
ax.set_ylabel("$\\Delta t\ \mathrm{(pulser) [ns]}$",fontsize=25)
ax.set_xlabel("$\\tau\ \mathrm{(análisis) [ns]}$",fontsize=25)
ticklabels_x = ax.get_xticklabels()
ticklabels_y = ax.get_yticklabels()
for label_x in ticklabels_x:
    label_x.set_fontsize(18)
    label_x.set_family('serif')
for label_y in ticklabels_y:
    label_y.set_fontsize(18)
    label_y.set_family('serif')
# Mediciones
ax.errorbar(tauAMCS*1E9, anchoPulserS*1E9, xerr= tauAMCErrorS*1E9, yerr= anchoPulserErrorS*1E9, fmt='.k')
ax.errorbar(tau*1E9, pulser*1E9, xerr= eTau*1E9, yerr= ePulser*1E9, fmt='.b')
# Ajustes
ax.plot(tauAMCS*1E9, p3a(tauAMCS)*1E9, 'k-', label='$\mathrm{post}$ $\mathrm{modificación}$')
ax.plot(tau*1E9, p3(tau)*1E9, 'k--', label='$\mathrm{anl150807}$')
ax.set_ylim(bottom=0, top= 450)
ax.set_xlim(left=90, right=230)
ax.legend(loc=2, fontsize=25)
ax.grid()
plt.savefig('curvaModificada.pdf')

# %% [markdown]
# Necesito una medición post modificación con neutrones de $\tau$ para obtener el $\Delta t$ con la nueva curva.

# %% [markdown]
# Entonces según el ajuste, los anchos temporales de los pulsos electrónicos son ahora mas grandes.
#
# Para un $\tau\simeq 120 \mathrm{\, ns}$ corresponde un ancho cuadrado de $\Delta t \simeq 138  \mathrm{\, ns}$

# %%
# Delta t para tau de anl160203 400V
# sería 125,9 +/- 0.7 ns
p3a(1.158e-07), p3a(1.158e-07+2.342e-10), p3a(1.158e-07-2.342e-10)
# Out:
# (1.2591115186034602e-07, 1.2660876448481647e-07, 1.2520851970633714e-07)

# %% [markdown]
# # Relación área - pico

# %% [markdown]
# pico de AMC vs. area de entrada (pulsos cuadrados)

# %%
fig = plt.figure(1, figsize=(9.5,6.5))
ax = plt.axes()
ax.set_ylabel("$\mathrm{Máximo}\ \mathrm{AMC}\ \mathrm{[V]}$",fontsize=25)
ax.set_xlabel("$\mathrm{área}\ \mathrm{pulser}\ \mathrm{[V \cdot ns]}$",fontsize=25)
ticklabels_x = ax.get_xticklabels()
ticklabels_y = ax.get_yticklabels()
for label_x in ticklabels_x:
    label_x.set_fontsize(18)
    label_x.set_family('serif')
for label_y in ticklabels_y:
    label_y.set_fontsize(18)
    label_y.set_family('serif')
# Mediciones
ax.errorbar(areaPulserS*1E9, maximoAMCS, xerr= areaPulserErrorS*1E9, yerr= maximoAMCErrorS, fmt='.k')
# ax.errorbar(tau*1E9, pulser*1E9, xerr= eTau*1E9, yerr= ePulser*1E9, fmt='.b')
# Ajustes
# ax.plot(areaPulserS*1E9, p3AreaMax(areaPulserS), 'k.', label='$\mathrm{Uh!}$ ')
#ax.set_ylim(bottom=0, top= 450)
#ax.set_xlim(left=90, right=230)
# ax.legend(loc=2, fontsize=25)
ax.grid()
plt.savefig('areaMaximoModificada.pdf')

# %%
type(res101)
# Out:
# pulAnl160106.resultadosComprimido
