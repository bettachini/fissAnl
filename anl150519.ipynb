# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# coding=utf-8

import time

# refresca de lo importado cada vez que se hace ejecución
# %load_ext autoreload
# %autoreload 2

path= './data/'

# %% [markdown]
# # Graficación, funciones

# %%
def darstellungNurZwei(T, Meas2, sav= None):
    '''
    T: times vector
    Meas2: Both channels 2D array
    sav: plot filename (eps)
    '''
        
    fig, (ax0, ax1) = plt.subplots(nrows=2, sharex=True)
    fig.set_size_inches(10,8)
    fig.subplots_adjust(hspace=0.000)

    ax0.plot(T, Meas2[0,:], 'y')
    # Make the y-axis label and tick labels match the line color.
    ax0.set_ylabel('ch 1 [V]', color='y')
    ax0.grid(True)

    ax1.plot(T, Meas2[1,:], 'c')
    ax1.set_ylabel('ch 2 [V]', color='c')
    ax1.set_xlabel('tiempo [s]')
    ax1.grid(True)
    
    if (sav):
        plt.savefig('./data/plots/'+ sav+ '.eps')
    else:
        plt.show()

# %%
# lee archivo npy en la ruta datei y grafica cada medición
def dateiDarstellung(datei, sav= None):
    '''
    str -> ()
    
    De un archivo npy grafica cada medición (índice), ambos canales.
    '''
    lu= np.load(datei)
    zeit= lu[0]
    messungenZahl= lu.shape[0]
    for i in range(1, messungenZahl, 2):
        ix= int((i-1)/2)
        print('medición = '+ str(ix), ', índiceCH1= '+ str(i))
        Meas2= np.vstack([lu[i], lu[i+1]])
        if (sav):
            savi= sav+ str(i)
            darstellungNurZwei(zeit, Meas2, savi)
        else:
            darstellungNurZwei(zeit, Meas2)

# %% [markdown]
# # Risetime, funciones

# %%
def baseAcq(acqFile, prop=0.25):
    '''
    (array, float) -> array
    
    De la primer fracción prop de ambos canales de todas las adquisiciones en acqFile,
    obtiene el promedio y dispersión que se asume como nivel de base
    grProm[0]: promedio ch1, grProm[1]: promedio ch2,
    grProm[2]: desviación estandard ch1, grProm[3]: desviación estandard ch2
    '''
    messungenZahl= acqFile.shape
    erstePunkten= int(messungenZahl[1]* prop)
    prom= np.zeros([int((messungenZahl[0]- 1)/ 2), 4])
    for i in range(1, messungenZahl[0], 2):
        ix= int((i-1)/2)
        ch1Erste= acqFile[i][0:erstePunkten-1]
        ch2Erste= acqFile[i+1][0:erstePunkten-1]
        prom[ix,0]= ch1Erste.mean()
        prom[ix,1]= ch2Erste.mean()
        prom[ix,2]= ch1Erste.std()
        prom[ix,3]= ch2Erste.std()
    return prom

# %%
def baseMeas2(Meas2, messungenZahl, prop=0.25):
    '''
    (array, array, float) -> array
    
    De la primer fracción prop de ambos canales en Meas2,
    obtiene el promedio y dispersión que se asume como nivel de base
    grProm[0]: promedio ch1, grProm[1]: promedio ch2,
    grProm[2]: desviación estandard ch1, grProm[3]: desviación estandard ch2
    '''
    erstePunkten= int(messungenZahl[1]* prop)
    ch1Erste= Meas2[0][0:erstePunkten-1]
    ch2Erste= Meas2[1][0:erstePunkten-1]
    return np.array([ch1Erste.mean(), ch2Erste.mean(), ch1Erste.std(), ch2Erste.std() ] )

# %%
def tauCeti2(T, Meas2, messungenZahl, prop):
    '''
    Calcula índices risetime como tiempo entre 10% y 90% de excursión entre nivel de base y máximo
   
    Meas2: array (2,:) con Meas2[0] canal 1, Meas2[0] canal 2, producto de np.vstack
    baseMeas2: base(Meas2)
    '''
    # niveles base
    bMeas2= baseMeas2(Meas2, messungenZahl, prop)

    # índice máximo
    maxIx= (Meas2[0].argmax(), Meas2[1].argmax() )

    # máximo promediado cercano
    rangoCercano= 20 # tres lecturas a izq y derecha
    maxCH1= (Meas2[0][maxIx[0]- rangoCercano: maxIx[0]+ rangoCercano]).mean()
    maxCH2= (Meas2[1][maxIx[1]- rangoCercano: maxIx[1]+ rangoCercano]).mean()

    # diferencia máximo- base
    # maxCH1= Meas2[0][maxIx[0]] # max CH1
    # maxCH2= Meas2[1][maxIx[1]] # max CH2
    # deltaV= np.array([Meas2[0][maxIx[0]]- bMeas2[0], Meas2[1][maxIx[1]]- bMeas2[1]])
    deltaV= np.array([maxCH1- bMeas2[0],maxCH2- bMeas2[1]]) # usa promediado cercano

    # Diferencias de potencial para 10%, 90% de excursión
    v10= bMeas2[0:2]+ 0.1* deltaV
    v90= bMeas2[0:2]+ 0.9* deltaV

    # Índices para primer potencial del pulso que exceda 10%, y último por debajo 90% 
    ixTau= np.array([0, 0, maxIx[0], maxIx[1]])
    while (Meas2[0,ixTau[0]]< v10[0]):
        ixTau[0]+= 1
    while (Meas2[1,ixTau[1]]< v10[1]):
        ixTau[1]+= 1
    while (Meas2[0,ixTau[2]]> v90[0]):
        ixTau[2]-= 1
    while (Meas2[1,ixTau[3]]> v90[1]):
        ixTau[3]-= 1
        
    return np.array([T[ixTau[2]]- T[ixTau[0]], T[ixTau[3]]- T[ixTau[1]] ])

# %%
def tauAMC2(acqData, prop= 0.25):
    '''
    Genera vectores de promedio y dispersión del risetime de ambos canales a partir de archivo acq*
    
    archivo: acq* 
    prop= porcentaje inferior del canal a promediar para obtener nivel de base     
    '''
    messungenZahl= acqData.shape

    # tiempo
    T= acqData[0]

    tauAMC= np.empty([int((messungenZahl[0]- 1)/ 2), 1])
    for i in range(1, messungenZahl[0], 2):
        Meas2= np.array([acqData[i], acqData[i+1] ] )
        ix= int((i-1)/2)
        tauAMC[ix]= tauCeti2(T, Meas2, messungenZahl, prop)[1]
    return tauAMC

# %%
def tauAMCz(npzData, prop= 0.25):
    '''
    Vectores risetime canal AMC de archivo acq comprimido
    
    npzData= numpy.lib.npyio.NpzFile
    prop= porcentaje inferior del canal a promediar para obtener nivel de base     
    '''
    FLUC= npzData['ch1']
    AMC= npzData['ch2']

    messungenZahl= AMC.shape

    # tiempo
    T= npzData['zeit']

    tauAMC= np.empty([messungenZahl[0], 1])
    for i in range(messungenZahl[0]):
        Meas2= np.array([FLUC[i], AMC[i] ] )
        tauAMC[i]= tauCeti2(T, Meas2, messungenZahl, prop)[1]
    return tauAMC

# %% [markdown]
# # Adquisiciones de 2560 pulsos

# %% [markdown]
# ## acq150519x01: CFP-35,  P_Ar=$3.12\frac{kgf}{cm^2}$ (relativa), P_N2=$0.02\frac{kgf}{cm^2}$ (absoluta)

# %%
a3= np.load('./data/acq150519x01.npy.npz')
a3_taus= tauAMCz(a3)
a3_taus.size
# Out:
# /usr/lib/python3/dist-packages/numpy/core/_methods.py:55: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)
# /usr/lib/python3/dist-packages/numpy/core/_methods.py:67: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 2560

# %%
n_n03, bins_n03, patches_n03= plt.hist(a3_taus, bins=120)

# %%
intermedio_n03 = np.ma.masked_greater(a3_taus, bins_n03[12])
primerCampana_n03= intermedio_n03.compressed()
n_n03p, bins_n03p, patches_n03p= plt.hist(primerCampana_n03, bins=40)

# %%
primerCampana_n03.mean(), primerCampana_n03.std()
# Out:
# (1.619224000000003e-07, 2.0094406640654996e-08)

# %%
# Filtar mas ruidosas
npzData= np.load('./data/exp150518x97.npy.npz')
prop= 0.25

# para el umbral necesito levantar el set
# OFFSET1 es el nivel de cero del canal FLUC
dico= np.load('./data/sets150518x97.npy') # set -> dict para verificar 
textDico= dico.item()
baseFLUC= textDico['OFFSET1']
FLUC= npzData['ch1']
AMC= npzData['ch2']
T= npzData['zeit']

messungenZahl= AMC.shape
ersteZahl= int(messungenZahl[1]*prop)

tauAMC= np.empty([messungenZahl[0], 1])
reject= np.empty([messungenZahl[0], 1],bool)
for i in range(messungenZahl[0]):
    Meas2= np.array([FLUC[i], AMC[i] ] )
    tauAMC[i]= tauCeti2(T, Meas2, messungenZahl, prop)[1]
    # rms primer porción canal FLUC
    # si rms> umbral: descartar
    erste= FLUC[i][0:ersteZahl]
    desv= 0
    for ix in range(ersteZahl):
        desv+= (erste[ix]- baseFLUC)**2
    desv/= ersteZahl
    if (desv>100):
        reject[i]=False
    else:
        reject[i]=True

# %%
tauAMCMasked= np.ma.masked_array(tauAMC, reject)

# %%
tauAMCMasked
# Out:
# masked_array(data =
#  [[--]
#  [1.9800000000000005e-07]
#  [1.5580000000000002e-06]
#  [--]
#  [--]
#  [--]
#  [1.982e-06]
#  [2.482e-06]
#  [--]
#  [2.296e-06]
#  [--]
#  [--]
#  [--]
#  [--]
#  [--]
#  [--]
#  [--]
#  [2.2880000000000004e-06]
#  [--]
#  [--]
#  [--]
#  [1.7780000000000002e-06]
#  [--]
#  [1.6440000000000003e-06]
#  [--]
#  [--]
#  [--]
#  [--]
#  [1.376e-06]
#  [--]
#  [--]
#  [--]
#  [2.4900000000000003e-06]
#  [--]
#  [--]
#  [2.2080000000000003e-06]
#  [1.8400000000000027e-07]
#  [--]
#  [1.5599999999999986e-07]
#  [--]
#  [--]
#  [--]
#  [--]
#  [--]
#  [2.25e-06]
#  [--]
#  [2.214e-06]
#  [--]
#  [--]
#  [--]
#  [--]
#  [--]
#  [--]
#  [--]
#  [--]
#  [--]
#  [--]
#  [--]
#  [2.002e-06]
#  [--]
#  [--]
#  [--]
#  [--]
#  [--]
#  [2.47e-06]
#  [2.919999999999999e-07]
#  [--]
#  [--]
#  [--]
#  [--]
#  [1.0220000000000003e-06]
#  [--]
#  [1.86e-07]
#  [--]
#  [--]
#  [1.0420000000000004e-06]
#  [2.486e-06]
#  [--]
#  [--]
#  [--]
#  [--]
#  [--]
#  [--]
#  [--]
#  [--]
#  [--]
#  [--]
#  [--]
#  [--]
#  [1.834e-06]
#  [--]
#  [--]
#  [--]
#  [--]
#  [--]
#  [--]
#  [1.6620000000000004e-06]
#  [1.2220000000000001e-06]
#  [1.58e-07]
#  [1.3999999999999993e-07]
#  [--]
#  [--]
#  [--]
#  [1.3400000000000033e-07]
#  [--]
#  [--]
#  [--]
#  [2.5300000000000003e-06]
#  [--]
#  [--]
#  [--]
#  [--]
#  [--]
#  [--]
#  [--]
#  [--]
#  [--]
#  [--]
#  [--]
#  [--]
#  [--]
#  [1.760000000000001e-07]
#  [--]
#  [--]
#  [7.220000000000002e-07]
#  [--]
#  [--]
#  [--]],
#              mask =
#  [[ True]
#  [False]
#  [False]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [ True]
#  [ True]
#  [False]
#  [ True]
#  [ True]
#  [ True]],
#        fill_value = 1e+20)

# %%
reject= np.empty([messungenZahl[0], 1],bool)

# %%
reject
# Out:
# array([[ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False]], dtype=bool)

# %%
np.empty

# %%
baseFLUC, plt.plot(FLUC[6])
# Out:
# (-65.0, [<matplotlib.lines.Line2D at 0x7f71e8617278>])

# %%
# set -> dict para verificar 
dico= np.load('./data/sets150518x97.npy')
textDico= dico.item() # np.array-> dict
# textDico['SCALE1']
textDico
# Out:
# {':TRIGGER:MAIN:EDGE:SOURCE': 'CH2',
#  'REFB': '0',
#  'PRESION_AR': '2.195',
#  'STYLE': 'VECTORS',
#  'WIDTH': '1.03E-3',
#  ':LANGUAGE': 'SPANISH',
#  ':HORIZONTAL:VIEW': 'MAIN',
#  'INVERT': 'OFF',
#  'POLARITY': 'NORMAL',
#  ':MEASUREMENT:MEAS2:TYPE': 'NONE',
#  ':MATH:FFT:VERTICAL:POSITION': '0.0E0',
#  ':DATA:ENCDG': 'RIBINARY',
#  'BANDWIDTH': 'OFF',
#  'WIDTH:POLARITY': 'POSITIVE',
#  'ESPECTRO': '160511v3',
#  ':MATH:FFT:HORIZONTAL:POSITION': '5.0E1',
#  ':CURSOR:VBARS:UNITS': 'SECONDS',
#  'SCALE2': 0.04,
#  'MAIN:SCALE': '5.0E-7',
#  ':CURSOR:FUNCTION': 'OFF',
#  'SLOPE': 'RISE',
#  ':HORIZONTAL:DELAY:SCALE': '1.0E-8',
#  'SELECT:SOURCE': 'CH2',
#  'INKSAVER': 'ON',
#  'POSITION': '0.0E0',
#  'LAYOUT': 'PORTRAIT',
#  'START': '1',
#  ':PICTBRIDGE:PAPERSIZE': 'DEFLT',
#  ':TRIGGER:MAIN:PULSE:SOURCE': 'CH2',
#  ':MEASUREMENT:MEAS5:TYPE': 'NONE',
#  ':VERBOSE': '1',
#  ':MEASUREMENT:MEAS3:TYPE': 'NONE',
#  'OFFSET1': -65.0,
#  'STOPAFTER': 'SEQUENCE',
#  ':LOCK': 'NONE',
#  'CONTRAST': '54',
#  ':TRIGGER:MAIN:LEVEL': '1.5E0',
#  'FORMAT': 'EPSIMAGE',
#  'MATH': '0',
#  'WHEN': 'NOTEQUAL',
#  ':MATH:DEFINE': '"CH1+CH2"',
#  ':TRIGGER:MAIN:VIDEO:SOURCE': 'CH2',
#  'IDPRINT': 'DEFLT',
#  ':MEASUREMENT:IMMED:TYPE': 'RISE',
#  'PAPERTYPE': 'DEFLT',
#  'PRINTQUAL': 'DEFLT',
#  'YUNIT': '"V"',
#  ':SELECT:CH1': '1',
#  ':MEASUREMENT:METHOD': 'AUTO',
#  'HV': '400',
#  ':TRIGGER:MAIN:MODE': 'NORMAL',
#  'IMAGESIZE': 'DEFLT',
#  'SCALE': '1.0E0',
#  'PERSISTENCE': '0',
#  ':MEASUREMENT:MEAS1:TYPE': 'RISE',
#  ':DISPLAY:FORMAT': 'YT',
#  'DESTINATION': 'REFA',
#  ':CURSOR:HBARS:POSITION1': '4.16E0',
#  'OFFSET2': -50.0,
#  'SYNC': 'FIELD',
#  'HOLDOFF:VALUE': '5.0E-7',
#  'FUENTE': 'Canberra 3002',
#  'STOP': '2500',
#  'PRESION_N2': '0',
#  'PORT': 'USB',
#  ':CH1:PROBE': '1.0E0',
#  'SCALE1': 0.0004,
#  ':ACQUIRE:MODE': 'SAMPLE',
#  'CH2': '1',
#  ':MEASUREMENT:MEAS4:TYPE': 'NONE',
#  ':AUTORANGE:SETTINGS': 'BOTH',
#  'CAMARA': 'CFP-25',
#  'POSITION2': '4.8E-1',
#  ':CH2:PROBE': '1.0E0',
#  'LINE': '1',
#  'POSITION1': '-1.66E-6',
#  ':SAVE:IMAGE:FILEFORMAT': 'EPSIMAGE',
#  ':HARDCOPY:BUTTON': 'SAVESALL',
#  'REFA': '0',
#  'VERTICAL:POSITION': '0.0E0',
#  'ELECTRONICA': 'Luis',
#  'NUMAVG': '128',
#  'STATE': '0',
#  'SOURCE1': 'CH2',
#  'CURRENTPROBE': '1.0E1',
#  'SOURCE': 'CH1',
#  'STANDARD': 'NTSC',
#  'TYPE': 'EDGE',
#  'DATEPRINT': 'DEFLT',
#  'COUPLING': 'DC'}

# %% [markdown]
# # Adquisición para mostrar ruido a Juan

# %%
dateiDarstellung('./data/acq150519n03.npy', 'acq150519n03') # segundo parámetro nombre base de archivos .png
# Out:
# medición = 0 , índiceCH1= 1
# medición = 1
#  , índiceCH1= 3
# medición = 2
#  , índiceCH1= 5
# medición = 3
#  , índiceCH1= 7
# medición = 4
#  , índiceCH1= 9
# medición = 5
#  , índiceCH1= 11
# medición = 6
#  , índiceCH1= 13
# medición = 7
#  , índiceCH1= 15
# medición = 8
#  , índiceCH1= 17
# medición = 9
#  , índiceCH1= 19
# medición = 10
#  , índiceCH1= 21
# medición = 11
#  , índiceCH1= 23
# medición = 12
#  , índiceCH1= 25
# medición = 13
#  , índiceCH1= 27
# medición = 14
#  , índiceCH1= 29
# medición = 15
#  , índiceCH1= 31
# medición = 16
#  , índiceCH1= 33
# medición = 17
#  , índiceCH1= 35
# medición = 18
#  , índiceCH1= 37
# medición = 19
#  , índiceCH1= 39
# medición = 20
#  , índiceCH1= 41
# medición = 21
#  , índiceCH1= 43
# medición = 22
#  , índiceCH1= 45
# medición = 23
#  , índiceCH1= 47
# medición = 24
#  , índiceCH1= 49
# medición = 25
#  , índiceCH1= 51
# medición = 26
#  , índiceCH1= 53
# medición = 27
#  , índiceCH1= 55
# medición = 28
#  , índiceCH1= 57
# medición = 29
#  , índiceCH1= 59
# medición = 30
#  , índiceCH1= 61
# medición = 31
#  , índiceCH1= 63
# medición = 32
#  , índiceCH1= 65
# medición = 33
#  , índiceCH1= 67
# medición = 34
#  , índiceCH1= 69
# medición = 35
#  , índiceCH1= 71
# medición = 36
#  , índiceCH1= 73
# medición = 37
#  , índiceCH1= 75
# medición = 38
#  , índiceCH1= 77
# medición = 39
#  , índiceCH1= 79
# /usr/lib/python3/dist-packages/matplotlib/pyplot.py:424: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
