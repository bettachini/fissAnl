# %%
# import numpy as np
# import matplotlib
# import matplotlib.pyplot as plt
# %matplotlib inline
# # coding=utf-8

import numpy as np
import matplotlib as mpl
mpl.use('nbagg') # gráficas interactivas e inline
import matplotlib.pyplot as plt

# refresca de lo importado cada vez que se hace ejecución
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Espectros - funciones

# %%
def leeOrtec(fileName):
    '''
    Entrada: archivo de texto generado por el GammaVision
    Salida: array de enteros con número de cuentas por canal
    '''
    # Lee archivo Ortec
    path='/oldhome/vbettachini/documents/cnea/campbell/espectros/'
    fl= open(path+fileName, 'r')
    datos= fl.readlines()
    fl.close()
    datos= datos[26:] # descarta preámbulo
    # transcribe cuentas a un array
    cuentas= np.array([],dtype= np.dtype('int8'))
    for linea in datos:
        # print(linea)
        intermedio= linea.split()
        for i in intermedio[1:]:
            cuentas= np.hstack(([cuentas, int(i) ] ) )
    return cuentas


def derstellungOrtec(filesList, leftI=0, rightI=150, bottomI=1E-3, topI=2E-1, norm=True):
    fig = plt.figure(figsize=(10,5))  # an empty figure with no axes
    ax_lst= fig.add_subplot(111)
    ax_lst.grid()
    ax_lst.set_xlim(leftI, rightI)
    ax_lst.set_ylim(bottomI, topI)
    ax_lst.set_xlabel('Canal')
    if norm:
        ax_lst.set_ylabel('Cuentas normalizadas')
    else:
        ax_lst.set_ylabel('Cuentas')
    for fileName in filesList:
        fileNameO= fileName+'.Txt'
        erste= leeOrtec(fileNameO)
        if norm:
            ax_lst.semilogy(erste/erste.sum(), label= fileName)
        else:
            ax_lst.semilogy(erste, label= fileName)
    ax_lst.legend()
    fig.show()

# %%
filesList= ['150430v3','150430v1']
derstellungOrtec(filesList, 20, 200, 1E-4, 1.5E-1)
# Out:
# <img src="data:image/png;base64,...">

# %%
[leftI, rightI, bottomI, topI]=[40, 250, 1E-4, 2E-1] # norm

# [leftI, rightI, bottomI, topI]=[30, 250, 1E-4, 3E2] # norm
# [leftI, rightI, bottomI, topI]=[30, 250, 1E-4, 3E-3] # norm False
norm=False

fig = plt.figure(figsize=(10,5))  # an empty figure with no axes
ax_lst= fig.add_subplot(111)
ax_lst.grid()
ax_lst.set_xlim(leftI, rightI)
ax_lst.set_ylim(bottomI, topI)
ax_lst.set_xlabel('Energía [arb.]')
if norm:
    ax_lst.set_ylabel('Cuentas normalizadas')
else:
    ax_lst.set_ylabel('Cuentas por segundo')
#    ax_lst.set_ylabel('Cuentas')

fileNameO= '150430v1'+'.Txt'
erste= leeOrtec(fileNameO)
zeit=318.199993
ax_lst.plot(erste/zeit, label= '4,45 atm',linestyle='-', color='k')
# ax_lst.plot(erste, label= '4,45 atm')
# Norm
# ax_lst.plot(erste/erste.sum(), label= '4,45 atm')
# ax_lst.semilogy(erste/erste.sum(), label= '3,91 atm')
    
fileNameO= '150430v3'+'.Txt'
zeit=851.839981
erste= leeOrtec(fileNameO)
ax_lst.plot(erste/zeit, label= '3,91 atm',linestyle='--', color='k')
# ax_lst.plot(erste, label= '3,91 atm')
# Norm
# ax_lst.plot(erste/erste.sum(), label= '3,91 atm')
# ax_lst.semilogy(erste/erste.sum(), label= '4,45 atm')

ax_lst.legend()
plt.savefig('../presentacion/graphs/spectra.pgf')
