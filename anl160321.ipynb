# %% [markdown]
# # Código auxilar

# %%
import numpy as np
import matplotlib as mpl
mpl.use('nbagg') # gráficas interactivas e inline
import matplotlib.pyplot as plt

# refresca de lo importado cada vez que se hace ejecución
# %load_ext autoreload
# %autoreload 2

# %%
def leeCanberreta(fileName):
    '''
    Este funciona
    '''
    
    import csv

    extension= '.csv'
    path='/oldhome/vbettachini/documents/cnea/campbell/espectros/canberreta/'
    canal= np.array([], dtype='int8')
    cuentas= np.array([], dtype='int8')
    with open(path+ fileName+ extension) as csvfile:
        lector = csv.reader(csvfile, delimiter='\t')
        for row in lector:
            canal= np.append(canal, np.int(row[0]) )
            cuentas= np.append(cuentas, np.int(row[1]) )
        sale= np.vstack(([canal, cuentas ] ) )
    return sale

# %% [markdown]
# # Serie mediciones fondo (cuarto neutrones) Canberreta

# %% [markdown]
# En simultaneo adquisiciones
# - `acq160321z01` ($10\,\mathrm{adq.} \sim 10\,\mathrm{mín}$)
#
# Espectros canberreta de $10\,\mathrm{mín}$
# - `160321ec01` con $N=20$
#
# Los próximos lo lanzo en simultáneo, nivel disparo AMC $1,96\,\mathrm{V}$
# - `160321ec02` con $N=20$, $30\,\mathrm{mín}$ / `acq160321z02` ($30\,\mathrm{adq.} \sim 30\,\mathrm{mín}$)
# - `160321ec03` con $N=35$, $30\,\mathrm{mín}$ / `acq160321z03` ($30\,\mathrm{adq.} \sim 30\,\mathrm{mín}$)

# %%
# N=20

archivoEspectro= '160321ec02'
espectroPrueba= leeCanberreta(archivoEspectro)

# Agrupo a 2048 canales
siz= int(espectroPrueba[1].size/2)
sale= np.empty(siz)
for i in range(siz):
    # print(i, i+siz)
    sale[i]= espectroPrueba[1][i]+ espectroPrueba[1][i+siz] 
    
plt.grid()
# plt.plot(np.arange(siz), sale, '.b')
plt.plot(np.arange(siz), np.log(sale), '.b')
plt.show()
# Out:
# -c:15: RuntimeWarning: divide by zero encountered in log
# <img src="data:image/png;base64,...">

# %%
archivoEspectro= '150715ec05_1'
espectroPrueba= leeCanberreta(archivoEspectro)

# Agrupo o 2048 canales
siz= int(espectroPrueba[1].size/2)
sale= np.empty(siz)
for i in range(siz):
    # print(i, i+siz)
    sale[i]= espectroPrueba[1][i]+ espectroPrueba[1][i+siz] 
    
plt.grid()
plt.plot(np.arange(siz), sale, '.b')
# plt.plot(np.arange(siz), np.log(sale), '.b')
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
# N=35
archivoEspectro= '160321ec03'
espectroPrueba= leeCanberreta(archivoEspectro)
# Agrupo a 2048 canales
siz= int(espectroPrueba[1].size/2)
sale= np.empty(siz)
for i in range(siz):
    # print(i, i+siz)
    sale[i]= espectroPrueba[1][i]+ espectroPrueba[1][i+siz] 
    
plt.grid()
# plt.plot(np.arange(siz), sale, '.b')
plt.plot(np.arange(siz), np.log(sale), '.b')
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# # Serie mediciones generador de pulsos

# %% [markdown]
# En simultáneo
# - `160321ec04` con $N=20$, $30\,\mathrm{mín}$ / `pul160321z01` ($1280\,\mathrm{adq.} \sim 30\,\mathrm{mín}$)

# %%
# N=20
archivoEspectro= '160321ec04'
espectroPrueba= leeCanberreta(archivoEspectro)
# Agrupo a 2048 canales
siz= int(espectroPrueba[1].size/2)
sale_N20= np.empty(siz)
for i in range(siz):
    # print(i, i+siz)
    sale_N20[i]= espectroPrueba[1][i]+ espectroPrueba[1][i+siz] 
    
plt.grid()
plt.xlim(xmax=400)
plt.plot(np.arange(siz), sale_N20, '.-b', lw=2) # lineal
# plt.plot(np.arange(siz), np.log(sale), '.b') # log
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
siz
# Out:
# 2048

# %%
sale.sum(), '{:e}'.format(sale.sum())
# Out:
# (1078318061.0, '1.078318e+09')

# %%
from rutAnl160216 import * # En rutinasAnalisis160129.py residen todas las funciones basadas en las desarroladas en pulAnl160106.ipynb

# %%
# `pul160321z01.npy.npz`
tipo= 'pul'
anne= 16 
mes= 3
dia= 21
rango= np.arange(1,2)
prop= 0.2
rechazo= 0.15
anchosPulser, areasPulser, maximosPulser, tausAMC, areasTotalAMC, areasSubidaAMC, maximosAMC= agregador2(tipo, anne, mes, dia, rango, prop, rechazo)

maximosAMC_pul160321z01= maximosAMC

# %%
# `pul160322zXX.npy.npz`
tipo= 'pul'
anne= 16 
mes= 3
dia= 22
rango= np.arange(1,6)
prop= 0.2
rechazo= 0.15
anchosPulser, areasPulser, maximosPulser, tausAMC, areasTotalAMC, areasSubidaAMC, maximosAMC= agregador2(tipo, anne, mes, dia, rango, prop, rechazo)

maximosAMC_pul160322= maximosAMC
maxs.size
# Out:
# 6400

# %%
# `pul160322zXX.npy.npz`
tipo= 'pul'
anne= 16 
mes= 3
dia= 22
rango= np.arange(6,8)
prop= 0.2
rechazo= 0.15
anchosPulser, areasPulser, maximosPulser, tausAMC, areasTotalAMC, areasSubidaAMC, maximosAMC= agregador2(tipo, anne, mes, dia, rango, prop, rechazo)

maximosAMC_pul160322_2= maximosAMC

# %%
maxs= np.hstack([maximosAMC_pul160321z01, maximosAMC_pul160322, maximosAMC_pul160322_2])
# plt.hist(maxs, bins=256)
# plt.show()

# %%
N= 20
div= 8
G= N/div
G, 108/G, 43.2*N/div
# Out:
# (2.5, 43.2, 108.0)

# %%
fig, ax1 = plt.subplots()

ax1.hist(maxs, bins=256)
# ax1.hist(maxs* ganancia, bins=256)
ax1.set_xlabel('Volt')
ax1.set_ylabel('Cuentas osciloscopio')

N= 20
factorDeEscala= .184037
ganancia_N20= N/factorDeEscala
div= 8
G= N/div
elNumero_N20= 109
ganancia_N20= 1/elNumero_N20

ax2 = ax1.twinx()
ax2.plot(np.arange(siz)* ganancia_N20, sale_N20, '.-b', lw=2, label='N=20, mult=1/109')
ax2.set_xlim([1,3])
ax2.yaxis.set_label_position("right")
ax2.set_ylabel('Cuentas MCA CNEA')

plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# Según la interfaz gráfica del Canberreta la ganancia ($G$) se calcula como $G=N/\mathrm{div}$ y $\mathrm{div}=4$ para $N=20$ por lo que $G=2.5$.
#
# Esto ne se corresponde con la ganancia estimada en $\sim 108$

# %%
N= 20
# factorDeEscala_play= .1839129989
factorDeEscala_play= .184037
ganancia_play= N/factorDeEscala_play
maxs.mean()*ganancia_play, np.argmax(sale), 1/224
# Out:
# (223.99997393526871, 224, 0.004464285714285714)

# %%
maxs.mean(), np.argmax(sale_N20), np.argmax(sale_N20)/109
# Out:
# (2.0612141601562524, 224, 2.0550458715596331)

# %% [markdown]
# ### Ensayo N=35

# %%
# N=20
archivoEspectro= '160322ec01'
espectroPrueba= leeCanberreta(archivoEspectro)
# Agrupo a 2048 canales
siz= int(espectroPrueba[1].size/2)
sale_N35= np.empty(siz)
for i in range(siz):
    # print(i, i+siz)
    sale_N35[i]= espectroPrueba[1][i]+ espectroPrueba[1][i+siz] 
    
plt.grid()
plt.xlim([100,240])
plt.plot(np.arange(siz), sale_N35, '.-b', lw=2) # lineal
# plt.plot(np.arange(siz), np.log(sale), '.b') # log
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
N= 35
div= 8
G= N/div
# factorDeEscala_play= .1839129989
factorDeEscala_play= .184037
ganancia_play= 81
maxs.mean()*ganancia_play, np.argmax(sale_N35)
# Out:
# (166.95834697265644, 167)

# %%
fig, ax1 = plt.subplots()

ax1.hist(maxs, bins=256)
# ax1.hist(maxs* ganancia, bins=256)
ax1.set_xlabel('Volt')
ax1.set_ylabel('Cuentas osciloscopio')

N= 35
factorDeEscala= .184037
ganancia_35= N/factorDeEscala
div= 8
G= N/div
elNumero_N35= 81
ganancia_N35= 1/elNumero_N35

ax2 = ax1.twinx()
ax2.plot(np.arange(siz)* ganancia_N35, sale_N35, '.-b', lw=2, label='N=35, mult=1/81')
ax2.set_xlim([1,3])
ax2.yaxis.set_label_position("right")
ax2.set_ylabel('Cuentas MCA CNEA')
# ax2.legend("mca ")

plt.legend()
ganancia, plt.show()
# Out:
# <img src="data:image/png;base64,...">
# (190.17914875813014, None)

# %%
1/81
# Out:
# 0.012345679012345678

# %%
maxs.mean()
# Out:
# 2.0612141601562524

# %% [markdown]
# # Ensayos

# %%
N= 20
ganancia= N/.1825
ganancia_ideal= N/.2

N, ganancia, ganancia_ideal
# Out:
# (20, 109.58904109589041, 100.0)
