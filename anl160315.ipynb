# %% [markdown]
# # A partir de mediciones hacer histograma de alturas y comparar con espectro Canberreta.

# %%
import numpy as np

# gráficas interactivas e inline
import matplotlib
matplotlib.use('nbagg')
import matplotlib.pyplot as plt

# refresca de lo importado cada vez que se hace ejecución
# %load_ext autoreload
# %autoreload 2


## Deprecated

# from rutAnl160216 import * # En rutinasAnalisis160129.py residen todas las funciones basadas en las desarroladas en pulAnl160106.ipynb

# %matplotlib inline
# coding=utf-8

# Usando mpld3
# %matplotlib inline
# import mpld3
# mpld3.enable_notebook()

# %%
def leeCanberreta(fileName):
    '''
    Este funciona
    '''
    
    import csv

    extension= '.csv'
    path='/oldhome/vbettachini/documents/cnea/campbell/espectros/canberreta/'
    canal= np.array([], dtype='int8')
    cuentas= np.array([], dtype='int8')
    with open(path+ fileName+ extension) as csvfile:
        lector = csv.reader(csvfile, delimiter='\t')
        for row in lector:
            canal= np.append(canal, np.int(row[0]) )
            cuentas= np.append(cuentas, np.int(row[1]) )
        sale= np.vstack(([canal, cuentas ] ) )
    return sale

# %%
# Último espectro canberreta `160203ec02.csv`
archivoEspectro= '160203ec02'
espectroPrueba= leeCanberreta(archivoEspectro)

# %%
plt.grid()
plt.xlim(20,4096)
plt.ylim(0,100)
plt.plot(espectroPrueba[0], espectroPrueba[1], '.b')
# plt.loglog(espectroPrueba[0], espectroPrueba[1], '.b')

# %%
# Último espectro canberreta `160203ec02.csv`
archivoEspectro= '160203ec01'
espectroPrueba= leeCanberreta(archivoEspectro)

# %%
plt.grid()
plt.xlim(20,4096)
plt.ylim(0,100)
plt.plot(espectroPrueba[0], espectroPrueba[1], '.b')
plt.show()

# %% [markdown]
# En resumidas cuentas no se ve un corno en ninguno de los dos espectros.

# %%
archivoEspectro= '160202ec03'
espectroPrueba= leeCanberreta(archivoEspectro)

# %%
plt.grid()
plt.xlim(20,4096)
plt.ylim(0,100)
plt.plot(espectroPrueba[0], espectroPrueba[1], '.b')
plt.show()

# %%
archivoEspectro= '150710ec01_8'
espectroPrueba= leeCanberreta(archivoEspectro)

plt.grid()
plt.xlim(20,4096)
plt.ylim(0,100)
plt.plot(espectroPrueba[0], espectroPrueba[1], '.b')
# plt.fill_between(espectroPrueba[0], 0, espectroPrueba[1],color='0.8')
plt.show()

# %%
x= np.linspace(1,10,10)

# %%
y= x**2

# %%
# plt.plot(x,y,'.-')
plt.fill_between(x,y)
plt.show()

# %%
siz= int(espectroPrueba[1].size/2)
sale= np.empty(siz)
for i in range(siz):
    # print(i, i+siz)
    sale[i]= espectroPrueba[1][i]+ espectroPrueba[1][i+siz]

# %%
plt.grid()
# plt.xlim(20,siz)
# plt.ylim(0,100)
plt.plot(np.arange(siz), sale, '.b')
plt.show()

# %%
sale.shape, espectroPrueba[1].shape, np.arange(siz).shape
# Out:
# ((2048,), (4096,), (2048,))

# %%
espectroPrueba[1][61]
# Out:
# 2306762

# %%
archivoEspectro= '160201ec01'
espectroPrueba= leeCanberreta(archivoEspectro)

plt.grid()
plt.xlim(20,4096)
plt.ylim(0,100)
plt.plot(espectroPrueba[0], espectroPrueba[1], '.b')
# plt.fill_between(espectroPrueba[0], 0, espectroPrueba[1],color='0.8')
plt.show()

# %%
siz= int(espectroPrueba[1].size/2)
sale= np.empty(siz)
for i in range(siz):
    # print(i, i+siz)
    sale[i]= espectroPrueba[1][i]+ espectroPrueba[1][i+siz] 
    
plt.grid()
# plt.xlim(20,siz)
# plt.ylim(0,100)
plt.plot(np.arange(siz), sale, '.b')
plt.show()

# %% [markdown]
# ## New start

# %%
archivoEspectro= '150716ec02_1'
espectroPrueba= leeCanberreta(archivoEspectro)

plt.grid()
plt.xlim(20,4096)
plt.ylim(0,100)
plt.plot(espectroPrueba[0], np.log(espectroPrueba[1]), '.b')
# plt.fill_between(espectroPrueba[0], 0, espectroPrueba[1],color='0.8')
plt.show()
# Out:
# -c:7: RuntimeWarning: divide by zero encountered in log
# <img src="data:image/png;base64,...">

# %% [markdown]
# Algo parece haber...

# %%
# Agrupo o 2048 canales
siz= int(espectroPrueba[1].size/2)
sale= np.empty(siz)
for i in range(siz):
    # print(i, i+siz)
    sale[i]= espectroPrueba[1][i]+ espectroPrueba[1][i+siz] 
    
plt.grid()
# plt.xlim(20,siz)
# plt.ylim(0,100)
plt.plot(np.arange(siz), sale, '.b')
# plt.plot(np.arange(siz), np.log(sale), '.b')
plt.show()
# Out:
# -c:11: RuntimeWarning: divide by zero encountered in log

# %% [markdown]
# Si. Efectivamente hay un pico en torno al canal 98.

# %% [markdown]
# Probemos nuevamente en una adquisición reciente.

# %%
archivoEspectro= '160203ec01'
espectroPrueba= leeCanberreta(archivoEspectro)

# Agrupo o 2048 canales
siz= int(espectroPrueba[1].size/2)
sale= np.empty(siz)
for i in range(siz):
    # print(i, i+siz)
    sale[i]= espectroPrueba[1][i]+ espectroPrueba[1][i+siz] 
    
plt.grid()
# plt.plot(np.arange(siz), sale, '.b')
plt.plot(np.arange(siz), np.log(sale), '.b')
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# Y no se vé nada. Solo un decaimiento exponencial.
