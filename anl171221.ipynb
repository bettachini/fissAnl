# %% [markdown]
# # Resumen
#
# Se hace uso de las rutinas que figuran en el código `rutAnl171221` que calcula en forma correcta diferencias de potencial y tiempos de las formas de onda recuperadas desde el osciloscopio Tektronix TDS2002B. Adaptación del notebook `pulAnl170605`.
#
# El cambio de rutina responde a las modificaciones del Amplificador de Amplio Rango producto del trabajo de Leandro Marzano.

# %%
#import matplotlib
import numpy as np
#import matplotlib.pyplot as plt

from rutAnl171221 import * # En rutAnl160216.py residen todas las funciones basadas en las desarroladas en pulAnl160106.ipynb

# %matplotlib inline
# coding=utf-8

# refresca de lo importado cada vez que se hace ejecución
# %load_ext autoreload
# %autoreload 2

import matplotlib.ticker as tkr # Para exportar gráficas en formato .pgf

# %% [markdown]
# # FC 165

# %%
# `acq171220z01.npy.npz`
tipo= 'acq'
anne= 17
mes= 12
dia= 20
rango= np.arange(1,3)
prop= 0.2
rechazo= 0.15
tausAMC, areasTotalAMC, areasSubidaAMC, maximosAMC= agregador2(tipo, anne, mes, dia, rango, prop, rechazo)

# %%
enmascaradaPorSobre= 1
mascara, tausAMCComprimidos = binner(tausAMC, enmascaradaPorSobre)
anchosPulser=1 # compatibilidad pulAnl160224
areasPulser=1 # compatibilidad pulAnl160224
maximosPulser=1  # compatibilidad pulAnl160224
mezclaOptima= todoEnmascarado3(tipo, mascara, anchosPulser, areasPulser, maximosPulser, tausAMCComprimidos, areasTotalAMC, areasSubidaAMC, maximosAMC)
# Out:
# puntos campana 148
# tauAMC= 	8.307e-08 	+/- 5.139e-10 	 s
# areaSubidaAMC= 	9.658e-08 	+/- 3.069e-09 	 Vs
# areaTotalAMC= 	2.638e-07 	+/- 7.946e-09 	 Vs
# maximoAMC=  	1.336e+00 	+/- 4.086e-02 	 V

# %% [markdown]
# # CFP 28 A Ar puro

# %%
# `acq171220z01.npy.npz`
tipo= 'acq'
anne= 17
mes= 12
dia= 20
rango= np.arange(3,15)
prop= 0.2
rechazo= 0.15
tausAMC, areasTotalAMC, areasSubidaAMC, maximosAMC= agregador2(tipo, anne, mes, dia, rango, prop, rechazo)

# %%
enmascaradaPorSobre= 0.5
mascara, tausAMCComprimidos = binner(tausAMC, enmascaradaPorSobre)
anchosPulser=1 # compatibilidad pulAnl160224
areasPulser=1 # compatibilidad pulAnl160224
maximosPulser=1  # compatibilidad pulAnl160224
mezclaOptima= todoEnmascarado3(tipo, mascara, anchosPulser, areasPulser, maximosPulser, tausAMCComprimidos, areasTotalAMC, areasSubidaAMC, maximosAMC)
# Out:
# puntos campana 1526
# tauAMC= 	1.384e-07 	+/- 4.951e-10 	 s
# areaSubidaAMC= 	1.211e-07 	+/- 1.333e-09 	 Vs
# areaTotalAMC= 	2.943e-07 	+/- 3.651e-09 	 Vs
# maximoAMC=  	9.915e-01 	+/- 8.919e-03 	 V

# %% [markdown]
# # CFP 28 B Ar puro

# %%
tipo= 'acq'
anne= 17
mes= 12
dia= 21
rango= np.arange(1,11)
prop= 0.2
rechazo= 0.15
tausAMC, areasTotalAMC, areasSubidaAMC, maximosAMC= agregador2(tipo, anne, mes, dia, rango, prop, rechazo)

# %%
enmascaradaPorSobre= 0.5
mascara, tausAMCComprimidos = binner(tausAMC, enmascaradaPorSobre)
anchosPulser=1 # compatibilidad pulAnl160224
areasPulser=1 # compatibilidad pulAnl160224
maximosPulser=1  # compatibilidad pulAnl160224
mezclaOptima= todoEnmascarado3(tipo, mascara, anchosPulser, areasPulser, maximosPulser, tausAMCComprimidos, areasTotalAMC, areasSubidaAMC, maximosAMC)
# Out:
# puntos campana 1273
# tauAMC= 	1.176e-07 	+/- 2.964e-10 	 s
# areaSubidaAMC= 	1.175e-07 	+/- 1.244e-09 	 Vs
# areaTotalAMC= 	2.784e-07 	+/- 2.755e-09 	 Vs
# maximoAMC=  	1.208e+00 	+/- 1.195e-02 	 V

# %% [markdown]
# # CFP 28 C

# %%
tipo= 'acq'
anne= 17
mes= 12
dia= 22
rango= np.arange(1,11)
prop= 0.2
rechazo= 0.15
tausAMC, areasTotalAMC, areasSubidaAMC, maximosAMC= agregador2(tipo, anne, mes, dia, rango, prop, rechazo)

# %%
enmascaradaPorSobre= 0.15
mascara, tausAMCComprimidos = binner(tausAMC, enmascaradaPorSobre)
anchosPulser=1 # compatibilidad pulAnl160224
areasPulser=1 # compatibilidad pulAnl160224
maximosPulser=1  # compatibilidad pulAnl160224
mezclaOptima= todoEnmascarado3(tipo, mascara, anchosPulser, areasPulser, maximosPulser, tausAMCComprimidos, areasTotalAMC, areasSubidaAMC, maximosAMC)
# Out:
# puntos campana 1142
# tauAMC= 	1.375e-07 	+/- 5.941e-10 	 s
# areaSubidaAMC= 	1.212e-07 	+/- 1.466e-09 	 Vs
# areaTotalAMC= 	2.886e-07 	+/- 3.253e-09 	 Vs
# maximoAMC=  	1.029e+00 	+/- 1.026e-02 	 V

# %% [markdown]
# # CFP 28 D

# %%
tipo= 'acq'
anne= 17
mes= 12
dia= 22
rango= np.arange(11,21)
prop= 0.2
rechazo= 0.15
tausAMC, areasTotalAMC, areasSubidaAMC, maximosAMC= agregador2(tipo, anne, mes, dia, rango, prop, rechazo)

# %%
enmascaradaPorSobre= 0.7
mascara, tausAMCComprimidos = binner(tausAMC, enmascaradaPorSobre)
anchosPulser=1 # compatibilidad pulAnl160224
areasPulser=1 # compatibilidad pulAnl160224
maximosPulser=1  # compatibilidad pulAnl160224
mezclaOptima= todoEnmascarado3(tipo, mascara, anchosPulser, areasPulser, maximosPulser, tausAMCComprimidos, areasTotalAMC, areasSubidaAMC, maximosAMC)
# Out:
# puntos campana 1254
# tauAMC= 	1.389e-07 	+/- 5.878e-10 	 s
# areaSubidaAMC= 	1.219e-07 	+/- 1.830e-09 	 Vs
# areaTotalAMC= 	2.898e-07 	+/- 3.963e-09 	 Vs
# maximoAMC=  	1.015e+00 	+/- 1.035e-02 	 V

# %% [markdown]
# ## Corriendo detector 2cm del centro del moderador

# %%
tipo= 'acq'
anne= 17
mes= 12
dia= 22
rango= np.arange(21,29)
prop= 0.2
rechazo= 0.15
tausAMC, areasTotalAMC, areasSubidaAMC, maximosAMC= agregador2(tipo, anne, mes, dia, rango, prop, rechazo)

# %%
enmascaradaPorSobre= 0.7
mascara, tausAMCComprimidos = binner(tausAMC, enmascaradaPorSobre)
anchosPulser=1 # compatibilidad pulAnl160224
areasPulser=1 # compatibilidad pulAnl160224
maximosPulser=1  # compatibilidad pulAnl160224
mezclaOptima= todoEnmascarado3(tipo, mascara, anchosPulser, areasPulser, maximosPulser, tausAMCComprimidos, areasTotalAMC, areasSubidaAMC, maximosAMC)
# Out:
# puntos campana 945
# tauAMC= 	1.456e-07 	+/- 9.536e-10 	 s
# areaSubidaAMC= 	1.354e-07 	+/- 2.708e-09 	 Vs
# areaTotalAMC= 	3.100e-07 	+/- 5.837e-09 	 Vs
# maximoAMC=  	1.013e+00 	+/- 1.229e-02 	 V
