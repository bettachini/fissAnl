# %% [markdown]
# # Resumen
#
# Se hace uso de las rutinas que figuran en el código `rutAnl171221` que calcula en forma correcta diferencias de potencial y tiempos de las formas de onda recuperadas desde el osciloscopio Tektronix TDS2002B. Adaptación del notebook `pulAnl170605`.
#
# El cambio de rutina responde a las modificaciones del Amplificador de Amplio Rango producto del trabajo de Leandro Marzano.

# %%
#import matplotlib
import numpy as np
#import matplotlib.pyplot as plt

from rutAnl171221 import * # En rutAnl160216.py residen todas las funciones basadas en las desarroladas en pulAnl160106.ipynb

# %matplotlib inline
# coding=utf-8

# refresca de lo importado cada vez que se hace ejecución
# %load_ext autoreload
# %autoreload 2

import matplotlib.ticker as tkr # Para exportar gráficas en formato .pgf

# %% [markdown]
# # FC 165 s/ fuente

# %%
tipo= 'acq'
anne= 18
mes= 2
dia= 26
rango= np.arange(1,3)
prop= 0.2
rechazo= 0.15
tausAMC, areasTotalAMC, areasSubidaAMC, maximosAMC= agregador2(tipo, anne, mes, dia, rango, prop, rechazo)

# %%
enmascaradaPorSobre= 0.4
mascara, tausAMCComprimidos = binner(tausAMC, enmascaradaPorSobre)
anchosPulser=1 # compatibilidad pulAnl160224
areasPulser=1 # compatibilidad pulAnl160224
maximosPulser=1  # compatibilidad pulAnl160224
mezclaOptima= todoEnmascarado3(tipo, mascara, anchosPulser, areasPulser, maximosPulser, tausAMCComprimidos, areasTotalAMC, areasSubidaAMC, maximosAMC)
# Out:
# puntos campana 244
# tauAMC= 	9.239e-08 	+/- 3.832e-10 	 s
# areaSubidaAMC= 	2.544e-07 	+/- 6.741e-09 	 Vs
# areaTotalAMC= 	6.367e-07 	+/- 1.504e-08 	 Vs
# maximoAMC=  	3.262e+00 	+/- 7.071e-02 	 V

# %% [markdown]
# # FC 165 c/ fuente

# %%
tipo= 'acq'
anne= 18
mes= 2
dia= 26
rango= np.arange(3,14)
prop= 0.2
rechazo= 0.15
tausAMC, areasTotalAMC, areasSubidaAMC, maximosAMC= agregador2(tipo, anne, mes, dia, rango, prop, rechazo)
# Out:
# /home/vbettachini/documents/cnea/fision/acquisition/analysis/rutAnl171221.py:157: RuntimeWarning: Mean of empty slice.
#   maxCh2= (Meas2[1][maxIx[1]- rangoCercano: maxIx[1]+ rangoCercano]).mean()
# /usr/lib/python3/dist-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/vbettachini/documents/cnea/fision/acquisition/analysis/rutAnl171221.py:156: RuntimeWarning: Mean of empty slice.
#   maxCh1= (Meas2[0][maxIx[0]- rangoCercano: maxIx[0]+ rangoCercano]).mean()

# %%
enmascaradaPorSobre= 0.8
mascara, tausAMCComprimidos = binner(tausAMC, enmascaradaPorSobre)
anchosPulser=1 # compatibilidad pulAnl160224
areasPulser=1 # compatibilidad pulAnl160224
maximosPulser=1  # compatibilidad pulAnl160224
mezclaOptima= todoEnmascarado3(tipo, mascara, anchosPulser, areasPulser, maximosPulser, tausAMCComprimidos, areasTotalAMC, areasSubidaAMC, maximosAMC)
# Out:
# puntos campana 1227
# tauAMC= 	6.529e-08 	+/- 5.944e-09 	 s
# areaSubidaAMC= 	5.451e-08 	+/- 2.763e-09 	 Vs
# areaTotalAMC= 	1.379e-07 	+/- 6.872e-09 	 Vs
# maximoAMC=  	6.345e-01 	+/- 3.503e-02 	 V

# %% [markdown]
# # CFP 28 # 3

# %%
tipo= 'acq'
anne= 18
mes= 2
dia= 27
rango= np.arange(1,11)
prop= 0.2
rechazo= 0.15
tausAMC, areasTotalAMC, areasSubidaAMC, maximosAMC= agregador2(tipo, anne, mes, dia, rango, prop, rechazo)

# %%
enmascaradaPorSobre= 0.3
mascara, tausAMCComprimidos = binner(tausAMC, enmascaradaPorSobre)
anchosPulser=1 # compatibilidad pulAnl160224
areasPulser=1 # compatibilidad pulAnl160224
maximosPulser=1  # compatibilidad pulAnl160224
mezclaOptima= todoEnmascarado3(tipo, mascara, anchosPulser, areasPulser, maximosPulser, tausAMCComprimidos, areasTotalAMC, areasSubidaAMC, maximosAMC)
# Out:
# puntos campana 1264
# tauAMC= 	9.610e-08 	+/- 1.888e-10 	 s
# areaSubidaAMC= 	2.788e-07 	+/- 2.956e-09 	 Vs
# areaTotalAMC= 	7.106e-07 	+/- 7.065e-09 	 Vs
# maximoAMC=  	3.514e+00 	+/- 3.250e-02 	 V

# %% [markdown]
# # CFP 28 # 2

# %%
tipo= 'acq'
anne= 18
mes= 2
dia= 27
rango= np.arange(11,21)
prop= 0.2
rechazo= 0.15
tausAMC, areasTotalAMC, areasSubidaAMC, maximosAMC= agregador2(tipo, anne, mes, dia, rango, prop, rechazo)

# %%
enmascaradaPorSobre= 0.3
mascara, tausAMCComprimidos = binner(tausAMC, enmascaradaPorSobre)
anchosPulser=1 # compatibilidad pulAnl160224
areasPulser=1 # compatibilidad pulAnl160224
maximosPulser=1  # compatibilidad pulAnl160224
mezclaOptima= todoEnmascarado3(tipo, mascara, anchosPulser, areasPulser, maximosPulser, tausAMCComprimidos, areasTotalAMC, areasSubidaAMC, maximosAMC)
# Out:
# puntos campana 1267
# tauAMC= 	9.714e-08 	+/- 2.169e-10 	 s
# areaSubidaAMC= 	2.755e-07 	+/- 3.084e-09 	 Vs
# areaTotalAMC= 	6.994e-07 	+/- 7.377e-09 	 Vs
# maximoAMC=  	3.413e+00 	+/- 3.354e-02 	 V

# %% [markdown]
# # CFP 28 # 1

# %%
tipo= 'acq'
anne= 18
mes= 2
dia= 27
rango= np.arange(21,31)
prop= 0.2
rechazo= 0.15
tausAMC, areasTotalAMC, areasSubidaAMC, maximosAMC= agregador2(tipo, anne, mes, dia, rango, prop, rechazo)

# %%
enmascaradaPorSobre= 0.15
mascara, tausAMCComprimidos = binner(tausAMC, enmascaradaPorSobre)
anchosPulser=1 # compatibilidad pulAnl160224
areasPulser=1 # compatibilidad pulAnl160224
maximosPulser=1  # compatibilidad pulAnl160224
mezclaOptima= todoEnmascarado3(tipo, mascara, anchosPulser, areasPulser, maximosPulser, tausAMCComprimidos, areasTotalAMC, areasSubidaAMC, maximosAMC)
# Out:
# puntos campana 1266
# tauAMC= 	9.611e-08 	+/- 2.156e-10 	 s
# areaSubidaAMC= 	2.778e-07 	+/- 3.170e-09 	 Vs
# areaTotalAMC= 	7.107e-07 	+/- 7.624e-09 	 Vs
# maximoAMC=  	3.491e+00 	+/- 3.396e-02 	 V

# %% [markdown]
# # CFP 28 # 4

# %%
tipo= 'acq'
anne= 18
mes= 2
dia= 27
rango= np.arange(31,41)
prop= 0.2
rechazo= 0.15
tausAMC, areasTotalAMC, areasSubidaAMC, maximosAMC= agregador2(tipo, anne, mes, dia, rango, prop, rechazo)

# %%
enmascaradaPorSobre= 0.5
mascara, tausAMCComprimidos = binner(tausAMC, enmascaradaPorSobre)
anchosPulser=1 # compatibilidad pulAnl160224
areasPulser=1 # compatibilidad pulAnl160224
maximosPulser=1  # compatibilidad pulAnl160224
mezclaOptima= todoEnmascarado3(tipo, mascara, anchosPulser, areasPulser, maximosPulser, tausAMCComprimidos, areasTotalAMC, areasSubidaAMC, maximosAMC)
# Out:
# puntos campana 1265
# tauAMC= 	9.631e-08 	+/- 2.040e-10 	 s
# areaSubidaAMC= 	2.709e-07 	+/- 2.874e-09 	 Vs
# areaTotalAMC= 	6.943e-07 	+/- 7.238e-09 	 Vs
# maximoAMC=  	3.434e+00 	+/- 3.329e-02 	 V

# %% [markdown]
# # CFP 28 # 5

# %%
tipo= 'acq'
anne= 18
mes= 2
dia= 27
rango= np.arange(41,51)
prop= 0.2
rechazo= 0.15
tausAMC, areasTotalAMC, areasSubidaAMC, maximosAMC= agregador2(tipo, anne, mes, dia, rango, prop, rechazo)

# %%
enmascaradaPorSobre= 0.3
mascara, tausAMCComprimidos = binner(tausAMC, enmascaradaPorSobre)
anchosPulser=1 # compatibilidad pulAnl160224
areasPulser=1 # compatibilidad pulAnl160224
maximosPulser=1  # compatibilidad pulAnl160224
mezclaOptima= todoEnmascarado3(tipo, mascara, anchosPulser, areasPulser, maximosPulser, tausAMCComprimidos, areasTotalAMC, areasSubidaAMC, maximosAMC)
# Out:
# puntos campana 1264
# tauAMC= 	9.600e-08 	+/- 2.161e-10 	 s
# areaSubidaAMC= 	2.771e-07 	+/- 3.144e-09 	 Vs
# areaTotalAMC= 	7.066e-07 	+/- 7.547e-09 	 Vs
# maximoAMC=  	3.512e+00 	+/- 3.451e-02 	 V

# %% [markdown]
# # FC 165

# %%
tipo= 'acq'
anne= 18
mes= 2
dia= 27
rango= np.arange(51,61)
prop= 0.2
rechazo= 0.15
tausAMC, areasTotalAMC, areasSubidaAMC, maximosAMC= agregador2(tipo, anne, mes, dia, rango, prop, rechazo)

# %%
enmascaradaPorSobre= 0.45
mascara, tausAMCComprimidos = binner(tausAMC, enmascaradaPorSobre)
anchosPulser=1 # compatibilidad pulAnl160224
areasPulser=1 # compatibilidad pulAnl160224
maximosPulser=1  # compatibilidad pulAnl160224
mezclaOptima= todoEnmascarado3(tipo, mascara, anchosPulser, areasPulser, maximosPulser, tausAMCComprimidos, areasTotalAMC, areasSubidaAMC, maximosAMC)
# Out:
# puntos campana 1273
# tauAMC= 	9.142e-08 	+/- 1.854e-10 	 s
# areaSubidaAMC= 	2.560e-07 	+/- 2.755e-09 	 Vs
# areaTotalAMC= 	6.584e-07 	+/- 7.063e-09 	 Vs
# maximoAMC=  	3.349e+00 	+/- 3.245e-02 	 V

# %% [markdown]
# # Cámara # 2 (redux)

# %%
tipo= 'acq'
anne= 18
mes= 2
dia= 28
rango= np.arange(1,11)
prop= 0.2
rechazo= 0.15
tausAMC, areasTotalAMC, areasSubidaAMC, maximosAMC= agregador2(tipo, anne, mes, dia, rango, prop, rechazo)

# %%
enmascaradaPorSobre= 0.4
mascara, tausAMCComprimidos = binner(tausAMC, enmascaradaPorSobre)
anchosPulser=1 # compatibilidad pulAnl160224
areasPulser=1 # compatibilidad pulAnl160224
maximosPulser=1  # compatibilidad pulAnl160224
mezclaOptima= todoEnmascarado3(tipo, mascara, anchosPulser, areasPulser, maximosPulser, tausAMCComprimidos, areasTotalAMC, areasSubidaAMC, maximosAMC)
# Out:
# puntos campana 1267
# tauAMC= 	9.716e-08 	+/- 2.238e-10 	 s
# areaSubidaAMC= 	2.737e-07 	+/- 3.128e-09 	 Vs
# areaTotalAMC= 	7.007e-07 	+/- 7.555e-09 	 Vs
# maximoAMC=  	3.395e+00 	+/- 3.353e-02 	 V

# %% [markdown]
# # Comparación $\tau$

# %%
tau_Ar= np.array([142.3, 138.4, 117.6, 137.5, 138.9])
tau_N2= np.array([96.1, 97.1, 96.1, 96.3, 96.0])
(tau_N2- tau_Ar)/tau_Ar
# Out:
# array([-0.3246662 , -0.2984104 , -0.18282313, -0.29963636, -0.30885529])
