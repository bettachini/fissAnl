# %% [markdown]
# La idea es generar histogramas de altura de pulsos determinados con el osciloscopio y comparar con el espectro canberreta.
#
# Se tomó la salida AMC de la Amplificador de Amplio Rango CNEA mod. E053-A0 (a.k.a. electrónica de Luís).
# Se midió y capturó con el osciloscopio.
# En simultaneo el multicanal canberreta realizó un espectro de altura de pulsos.

# %%
import numpy as np
import matplotlib as mpl
mpl.use('nbagg') # gráficas interactivas e inline
import matplotlib.pyplot as plt

# refresca de lo importado cada vez que se hace ejecución
# %load_ext autoreload
# %autoreload 2

# %%
def leeCanberreta(fileName):
    '''
    Este funciona
    '''
    
    import csv

    extension= '.csv'
    path='/oldhome/vbettachini/documents/cnea/campbell/espectros/canberreta/'
    canal= np.array([], dtype='int8')
    cuentas= np.array([], dtype='int8')
    with open(path+ fileName+ extension) as csvfile:
        lector = csv.reader(csvfile, delimiter='\t')
        for row in lector:
            canal= np.append(canal, np.int(row[0]) )
            cuentas= np.append(cuentas, np.int(row[1]) )
        sale= np.vstack(([canal, cuentas ] ) )
    return sale

# %% [markdown]
# # Comparación para CFP-35

# %% [markdown]
# Apenas despúes de cambio de cable y tiempo eleectrónica (100 ns):
# * espectro canberreta 160201ec01
# * adquisición osciloscopio acq160201z02

# %%
# Espectro canberreta

archivoEspectro= '160201ec01'
espectroPrueba= leeCanberreta(archivoEspectro)
# Agrupo a 2048 canales
siz= int(espectroPrueba[1].size/2)
sale_N40= np.empty(siz)
for i in range(siz):
    # sale_N40[i]= espectroPrueba[1][i] # resolución completa: 4096canales
    sale_N40[i]= espectroPrueba[1][i]+ espectroPrueba[1][i+siz] # mitad de resolución: 2048 canales 
    
plt.grid()
# plt.xlim([30,150])
# plt.plot(np.arange(siz), sale_N40, '.-b', lw=2) # lineal
plt.xlim([30,1024])
plt.plot(np.arange(siz), np.log(sale_N40), '.b') # log
plt.show()
plt.close()
# Out:
# -c:16: RuntimeWarning: divide by zero encountered in log
# <img src="data:image/png;base64,...">

# %%
# Funciones de análisis de adquisiciones con osciloscopio
from rutAnl160201 import * # En rutinasAnalisis160129.py residen todas las funciones basadas en las desarroladas en pulAnl160106.ipynb

# %%
# 160201z02
tipo= 'acq'
anne= 16
mes= 2
dia= 1
acqN= 2
npzData= np.load(dataPathFile(tipo, anne, mes, dia, acqN))

# tiempos de subida (risetime AMC)
finales= agrupadorTauMaxAreas(npzData)
taus= finales[:,0] # [s]
neufBin(taus, 0.15, 'T [s]')

plt.show()
plt.close()
# Out:
# <img src="data:image/png;base64,...">

# %%
maxs= finales[:,1]
# Out:
# (2.7932489636479545, 40, 0.49382716049382713)

# %%
fig, ax1 = plt.subplots()

ax1.hist(maxs, bins=256)
# ax1.hist(maxs* ganancia, bins=256)
ax1.set_xlabel('Volt')
ax1.set_ylabel('Cuentas osciloscopio')

elNumero_N40= 81*(26/45)*0.4
ganancia_N40= 1/elNumero_N40

ax2 = ax1.twinx()
ax2.plot(np.arange(siz)* ganancia_N40, sale_N40, '.-b', lw=2, label='N=40, mult=1/81')
ax2.set_xlim([1.5,5.5])
ax2.yaxis.set_label_position("right")
ax2.set_ylabel('Cuentas MCA CNEA')

plt.legend()
plt.show()
plt.close()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# # Hasta acá

# %%
# Adquisición osciloscopio
# `acq160201z02.npy.npz`
tipo= 'acq'
anne= 16 
mes= 2
dia= 1
rango= np.arange(2,3)
prop= 0.2
rechazo= 0.15
anchosPulser, areasPulser, maximosPulser, tausAMC, areasTotalAMC, areasSubidaAMC, maximosAMC= agregador2(tipo, anne, mes, dia, rango, prop, rechazo)

maxs= maximosAMC
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-4a74ebbcf107> in <module>()
#       8 prop= 0.2
#       9 rechazo= 0.15
# ---> 10 anchosPulser, areasPulser, maximosPulser, tausAMC, areasTotalAMC, areasSubidaAMC, maximosAMC= agregador2(tipo, anne, mes, dia, rango, prop, rechazo)
#      11
#      12 maxs= maximosAMC
#
# ValueError: need more than 4 values to unpack

# %% [markdown]
# ## CFP 35 Depletado

# %% [markdown]
# Últimos, supuestamente con el contador depletado de gas:
# * espectro canberreta 160202ec03
# * adquisición osciloscopio acq160202z05

# %%
archivoEspectro= '160202ec03'
espectroPrueba= leeCanberreta(archivoEspectro)
# Agrupo a 2048 canales
siz= int(espectroPrueba[1].size/2)
sale_N40= np.empty(siz)
for i in range(siz):
    # print(i, i+siz)
    sale_N40[i]= espectroPrueba[1][i]+ espectroPrueba[1][i+siz] 
    
plt.grid()
plt.xlim([100,240])
plt.plot(np.arange(siz), sale_N40, '.-b', lw=2) # lineal
# plt.plot(np.arange(siz), np.log(sale), '.b') # log
plt.show()
plt.close()
# Out:
# <img src="data:image/png;base64,...">

# %%
espectroPrueba
# Out:
# array([[   0,    1,    2, ..., 4093, 4094, 4095],
#        [   0,    0,    0, ...,    0,    0,    0]])

# %%
from rutAnl160216 import * # En rutinasAnalisis160129.py residen todas las funciones basadas en las desarroladas en pulAnl160106.ipynb

# %%
# `pul160329z01.npy.npz`
tipo= 'pul'
anne= 16 
mes= 3
dia= 22
rango= np.arange(1,3)
prop= 0.2
rechazo= 0.15
anchosPulser, areasPulser, maximosPulser, tausAMC, areasTotalAMC, areasSubidaAMC, maximosAMC= agregador2(tipo, anne, mes, dia, rango, prop, rechazo)

# %%
maxs= maximosAMC

# %%
maxs.mean(), np.argmax(sale_N40), np.argmax(sale_N40)/81
# Out:
# (2.0616285156250034, 166, 2.0493827160493829)

# %%
fig, ax1 = plt.subplots()

ax1.hist(maxs, bins=256)
# ax1.hist(maxs* ganancia, bins=256)
ax1.set_xlabel('Volt')
ax1.set_ylabel('Cuentas osciloscopio')

elNumero_N40= 81
ganancia_N40= 1/elNumero_N40

ax2 = ax1.twinx()
ax2.plot(np.arange(siz)* ganancia_N40, sale_N40, '.-b', lw=2, label='N=40, mult=1/81')
ax2.set_xlim([1,3])
ax2.yaxis.set_label_position("right")
ax2.set_ylabel('Cuentas MCA CNEA')

plt.legend()
plt.show()
plt.close()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# No me gusta el desbalance, por lo que largo una nueva adquisición 72 minutos pulsos BL-2 `pul160329z02`: 3*1028 adquisiciones.
#
# En simultáneo adquisición, ahora del doble, 60 minutos con canberreta `160329ec02`: $N=40$, 4096 canales.
#
# La idea es graficar el conjunto de pulsos `pul160329z01` y `pul160329z02` (doble número) con el nuevo espectro (doble tiempo).

# %%
# `pul160329z01-2.npy.npz`
tipo= 'pul'
anne= 16 
mes= 3
dia= 22
rango= np.arange(1,3)
prop= 0.2
rechazo= 0.15
anchosPulser, areasPulser, maximosPulser, tausAMC, areasTotalAMC, areasSubidaAMC, maximosAMC2= agregador2(tipo, anne, mes, dia, rango, prop, rechazo)

# %%
archivoEspectro= '160329ec02'
espectroPrueba= leeCanberreta(archivoEspectro)
# Agrupo a 2048 canales
siz= int(espectroPrueba[1].size/2)
sale_N402= np.empty(siz)
for i in range(siz):
    # print(i, i+siz)
    sale_N402[i]= espectroPrueba[1][i]+ espectroPrueba[1][i+siz]

# %%
fig, ax1 = plt.subplots()

ax1.hist(maximosAMC2, bins=256)
# ax1.hist(maxs* ganancia, bins=256)
ax1.set_xlabel('Volt')
ax1.set_ylabel('Cuentas osciloscopio')

elNumero_N402= 81
ganancia_N402= 1/elNumero_N40

ax2 = ax1.twinx()
ax2.plot(np.arange(siz)* ganancia_N402, sale_N402, '.-b', lw=2, label='N=40, mult=1/81')
ax2.set_xlim([1,3])
ax2.yaxis.set_label_position("right")
ax2.set_ylabel('Cuentas MCA CNEA')

plt.legend()
plt.show()
plt.close()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# # Comparación para Centronic FC-165

# %% [markdown]
# Usaré:
# * espectro canberreta
# * adquisición osciloscopio acq150427c01
